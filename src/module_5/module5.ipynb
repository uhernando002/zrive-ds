# %% [markdown]
# ## Module 5: Analyse, diagnose and improve a model​
#
# In the excercise of this week you will be working with financial data in order to (hopefully) find a portfolio of equities which outperform SP500. The data that you are gonna work with has two main sources:
# * Financial data from the companies extracted from the quarterly company reports (mostly extracted from [macrotrends](https://www.macrotrends.net/) so you can use this website to understand better the data and get insights on the features, for example [this](https://www.macrotrends.net/stocks/charts/AAPL/apple/revenue) is the one corresponding to APPLE)
# * Stock prices, mostly extracted from [morningstar](https://indexes.morningstar.com/page/morningstar-indexes-empowering-investor-success?utm_source=google&utm_medium=cpc&utm_campaign=MORNI%3AG%3ASearch%3ABrand%3ACore%3AUK%20MORNI%3ABrand%3ACore%3ABroad&utm_content=engine%3Agoogle%7Ccampaignid%3A18471962329%7Cadid%3A625249340069&utm_term=morningstar%20index&gclid=CjwKCAjws9ipBhB1EiwAccEi1Fu6i20XHVcxFxuSEtJGF0If-kq5-uKnZ3rov3eRkXXFfI5j8QBtBBoCayEQAvD_BwE), which basically tell us how the stock price is evolving so we can use it both as past features and the target to predict).
#
# Before going to the problem that we want to solve, let's comment some of the columns of the dataset:

# %% [markdown]
# * `Ticker`: a [short name](https://en.wikipedia.org/wiki/Ticker_symbol) to identify the equity (that you can use to search in macrotrends)
# * `date`: the date of the company report (normally we are gonna have 1 every quarter). This is for informative purposes but you can ignore it when modeling.
# * `execution date`: the date when we would had executed the algorithm for that equity. We want to execute the algorithm once per quarter to create the portfolio, but the release `date`s of all the different company reports don't always match for the quarter, so we just take a common `execution_date` for all of them.
# * `stock_change_div_365`: what is the % change of the stock price (with dividens) in the FOLLOWING year after `execution date`.
# * `sp500_change_365`: what is the % change of the SP500 in the FOLLOWING year after `execution date`.
# * `close_0`: what is the price at the moment of `execution date`
# * `stock_change__minus_120` what is the % change of the stock price in the last 120 days
# * `stock_change__minus_730`: what is the % change of the stock price in the last 730 days
#
# The rest of the features can be divided beteween financial features (the ones coming from the reports) and technical features (coming from the stock price). We leave the technical features here as a reference:

# %%
technical_features = ['close_0', 'close_sp500_0', 'close_365', 'close_sp500_365',
       'close__minus_120', 'close_sp500__minus_120', 'close__minus_365',
       'close_sp500__minus_365', 'close__minus_730', 'close_sp500__minus_730',
       'stock_change_365','stock_change_div_365', 'sp500_change_365', 'stock_change__minus_120',
       'sp500_change__minus_120', 'stock_change__minus_365',
       'sp500_change__minus_365', 'stock_change__minus_730','sp500_change__minus_730',
       'std__minus_365','std__minus_730','std__minus_120']

# %% [markdown]
# The problem that we want to solve is basically find a portfolio of `top_n` tickers (initially set to 10) to invest every `execution date` (basically once per quarter) and the goal is to have a better return than `SP500` in the following year. The initial way to model this is to have a binary target which is 1 when `stock_change_div_365` - `sp500_change_365` (the difference between the return of the equity and the SP500 in the following year) is positive or 0 otherwise. So we try to predict the probability of an equity of improving SP500 in the following year, we take the `top_n` equities and compute their final return.

# %%
import pandas as pd
import re
import numpy as np
import lightgbm as lgb
from plotnine import ggplot, geom_histogram, aes, geom_col, coord_flip,geom_bar,scale_x_discrete, geom_point, theme,element_text, geom_boxplot

# %%
# number of trees in lightgbm
n_trees = 40
minimum_number_of_tickers = 1500
# Number of the quarters in the past to train
n_train_quarters = 36
# number of tickers to make the portfolio
top_n = 10

# %%
data_set = pd.read_feather("/home/unai/datasets/financials_against_return.feather")

# %% [markdown]
# Remove these quarters which have leas than `minimum_number_of_tickers` tickers:

# %%
df_quarter_lengths = data_set.groupby(["execution_date"]).size().reset_index().rename(columns = {0:"count"})
data_set = pd.merge(data_set, df_quarter_lengths, on = ["execution_date"])
data_set = data_set[data_set["count"]>=minimum_number_of_tickers]

# %%
data_set.shape
# Out:
# (170483, 145)

# %% [markdown]
# Create the target:

# %%
data_set["diff_ch_sp500"] = data_set["stock_change_div_365"] - data_set["sp500_change_365"]

data_set.loc[data_set["diff_ch_sp500"]>0,"target"] = 1
data_set.loc[data_set["diff_ch_sp500"]<0,"target"] = 0

data_set["target"].value_counts()
# Out:
# target
# 0.0    82437
# 1.0    73829
# Name: count, dtype: int64

# %% [markdown]
# This function computes the main metric that we want to optimize: given a prediction where we have probabilities for each equity, we sort the equities in descending order of probability, we pick the `top_n` ones, and we we weight the returned `diff_ch_sp500` by the probability:

# %%
def get_weighted_performance_of_stocks(df,metric):
    df["norm_prob"] = 1/len(df)
    return np.sum(df["norm_prob"]*df[metric])

def get_top_tickers_per_prob(preds):
    if len(preds) == len(train_set):
        data_set = train_set.copy()
    elif len(preds) == len(test_set):
        data_set = test_set.copy()
    else:
        assert ("Not matching train/test")
    data_set["prob"] = preds
    data_set = data_set.sort_values(["prob"], ascending = False)
    data_set = data_set.head(top_n)
    return data_set

# main metric to evaluate: average diff_ch_sp500 of the top_n stocks
def top_wt_performance(preds, train_data):
    top_dataset = get_top_tickers_per_prob(preds)
    return "weighted-return", get_weighted_performance_of_stocks(top_dataset,"diff_ch_sp500"), True

# %% [markdown]
# We have created for you a function to make the `train` and `test` split based on a `execution_date`:

# %%
pd.set_option('display.max_columns', None)

# %%
data_set.head()
# Out:
#   Ticker       date  AssetTurnover  CashFlowFromFinancialActivities  \
# 0      A 2005-01-31         0.1695                           81.000
# 1   NDSN 2005-01-31         0.2248                           -3.366
# 2   HURC 2005-01-31         0.3782                            0.483
# 3    NRT 2005-01-31         1.0517                              NaN
# 4    HRL 2005-01-31         0.4880                          -12.075
#
#    CashFlowFromInvestingActivities  CashFlowFromOperatingActivities  \
# 0                          -57.000                          137.000
# 1                           10.663                            7.700
# 2                           -0.400                            2.866
# 3                              NaN                              NaN
# 4                         -113.077                           83.476
#
#    CashOnHand  ChangeInAccountsPayable  ChangeInAccountsReceivable  \
# 0   2483.0000                    5.000                      44.000
# 1     62.6220                      NaN                         NaN
# 2     11.3030                    0.156                       0.854
# 3      4.9015                      NaN                         NaN
# 4    145.2050                      NaN                      17.084
#
#    ChangeInAssetsLiabilities  ChangeInInventories  CommonStockDividendsPaid  \
# 0                     -5.000              -13.000                       NaN
# 1                    -21.145                  NaN                    -5.800
# 2                     -0.027               -1.487                       NaN
# 3                        NaN                  NaN                       NaN
# 4                      3.539              -17.176                   -15.516
#
#    CommonStockNet  ComprehensiveIncome  CostOfGoodsSold  CurrentRatio  \
# 0           5.000              215.000          621.000        2.6251
# 1          12.253               -4.625           83.625        2.1651
# 2           0.618               -3.529           20.506        2.0116
# 3             NaN                  NaN              NaN        1.0161
# 4           8.100              -23.242          959.363        1.9314
#
#    DaysSalesInReceivables  DebtIssuanceRetirementNet_minus_Total  \
# 0                 70.2475                                 23.000
# 1                 81.0339                                  0.905
# 2                 49.5467                                 -0.180
# 3                     NaN                                    NaN
# 4                 19.9872                                 -0.015
#
#    DebtEquityRatio      EBIT  EBITMargin    EBITDA  EBITDAMargin  \
# 0           0.3052  152.0000      3.1353  344.0000           NaN
# 1           0.4187   95.0000     12.4891  120.5480           NaN
# 2           0.1003   14.2120     11.7470   15.4800           NaN
# 3              NaN   20.6192    100.0000   20.6192           NaN
# 4           0.2601  431.1324      8.4773  535.7724           NaN
#
#    FinancialActivities_minus_Other  GoodwillAndIntangibleAssets  GrossMargin  \
# 0                              NaN                      459.000      48.7624
# 1                              NaN                      349.445      56.0253
# 2                              NaN                          NaN      32.2026
# 3                              NaN                          NaN     100.0000
# 4                            4.685                      552.231      24.5446
#
#    GrossProfit  IncomeAfterTaxes  IncomeFromContinuousOperations  \
# 0     591.0000           43.0000                         51.0000
# 1     106.5410           14.3660                         14.3660
# 2       9.7400            3.0300                          3.0300
# 3       5.1548            4.8351                          4.8351
# 4     312.0681           64.6330                         64.6330
#
#    IncomeFromDiscontinuedOperations  IncomeTaxes  Inventory  \
# 0                              52.0       15.000   1037.000
# 1                               NaN        6.917     88.409
# 2                               NaN        0.369     31.394
# 3                               NaN          NaN        NaN
# 4                               NaN       38.054    472.865
#
#    InventoryTurnoverRatio  InvestingActivities_minus_Other  LongTermDebt  \
# 0                  0.5988                           -9.000      1150.000
# 1                  0.9459                              NaN       147.612
# 2                  0.6532                            0.277         4.106
# 3                     NaN                              NaN           NaN
# 4                  2.0288                              NaN       361.495
#
#    Long_minus_TermInvestments  Long_minus_termDebtCapital  \
# 0                         NaN                      0.2338
# 1                         NaN                      0.2575
# 2                       5.878                      0.0852
# 3                         NaN                         NaN
# 4                      58.305                      0.1995
#
#    NetAcquisitionsDivestitures  NetCashFlow  NetChangeInIntangibleAssets  \
# 0                      -10.000      672.000                          NaN
# 1                          NaN       63.368                          NaN
# 2                          NaN       12.216                       -0.137
# 3                          NaN          NaN                          NaN
# 4                     -188.243     -166.704                          NaN
#
#    NetChangeInInvestments_minus_Total  NetChangeInLong_minus_TermInvestments  \
# 0                             -10.000                                -10.000
# 1                              13.799                                    NaN
# 2                              -0.054                                    NaN
# 3                                 NaN                                    NaN
# 4                              99.413                                 99.413
#
#    NetChangeInPropertyPlantAndEquipment  \
# 0                               -28.000
# 1                                -3.136
# 2                                -0.486
# 3                                   NaN
# 4                               -24.247
#
#    NetChangeInShort_minus_termInvestments  NetCommonEquityIssuedRepurchased  \
# 0                                     NaN                            58.000
# 1                                  13.799                             1.529
# 2                                  -0.054                             0.663
# 3                                     NaN                               NaN
# 4                                     NaN                            -1.229
#
#    NetCurrentDebt  NetIncome  NetIncomeLoss  NetLong_minus_TermDebt  \
# 0          23.000   103.0000        103.000                     NaN
# 1           2.078    14.3660         14.366                  -1.173
# 2             NaN     3.0300          3.030                  -0.180
# 3             NaN     4.8351          0.000                     NaN
# 4             NaN    64.6330         64.633                  -0.015
#
#    NetProfitMargin  NetTotalEquityIssuedRepurchased  OperatingExpenses  \
# 0           8.4984                           58.000           1174.000
# 1           7.5545                            1.529            166.416
# 2          10.0179                            0.663             26.693
# 3          93.7981                              NaN                NaN
# 4           5.0835                           -1.229           1166.575
#
#    OperatingIncome  OperatingMargin  OtherCurrentAssets  OtherIncome  \
# 0          38.0000           3.1353             183.000          NaN
# 1          23.7500          12.4891                 NaN          NaN
# 2           3.5530          11.7470               3.232          NaN
# 3           5.1548         100.0000                 NaN          NaN
# 4         104.8561           8.2471                 NaN          NaN
#
#    OtherLong_minus_TermAssets  OtherNon_minus_CashItems  \
# 0                     807.000                    33.000
# 1                      15.758                     0.055
# 2                         NaN                     0.096
# 3                       0.000                       NaN
# 4                     167.312                   -14.895
#
#    OtherNon_minus_CurrentLiabilities  OtherOperatingIncomeOrExpenses  \
# 0                            461.000                             NaN
# 1                            102.491                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                             47.327                             NaN
#
#    OtherShareHoldersEquity  Pre_minus_PaidExpenses  Pre_minus_TaxIncome  \
# 0                      NaN                     NaN              58.0000
# 1                      NaN                   8.113              21.2830
# 2                      NaN                     NaN               3.3990
# 3                      0.0                     NaN               4.8351
# 4                      NaN                  14.092             102.6870
#
#    Pre_minus_TaxProfitMargin  PropertyPlantAndEquipment  \
# 0                     4.7855                   1235.000
# 1                    11.1918                    112.524
# 2                    11.2379                      8.539
# 3                    93.7981                        NaN
# 4                     8.0765                    817.753
#
#    ROA_minus_ReturnOnAssets  ROE_minus_ReturnOnEquity  \
# 0                    0.7133                    1.3535
# 1                    1.6984                    3.3744
# 2                    3.7886                    6.8704
# 3                   98.6454                 6237.4080
# 4                    2.4807                    4.4557
#
#    ROI_minus_ReturnOnInvestment  Receivables  ReceiveableTurnover  \
# 0                        1.0370      946.000               1.2812
# 1                        2.5057      171.221               1.1106
# 2                        6.2853       16.651               1.8165
# 3                     6237.4080          NaN                  NaN
# 4                        3.5668      282.359               4.5029
#
#    ResearchAndDevelopmentExpenses  RetainedEarningsAccumulatedDeficit  \
# 0                           700.0                          -1707.0000
# 1                             NaN                            567.1850
# 2                             NaN                             -0.4120
# 3                             NaN                              0.0775
# 4                             NaN                           1461.1110
#
#    ReturnOnTangibleEquity    Revenue  SGAExpenses  ShareHolderEquity  \
# 0                  1.5413  4848.0000      378.000          3768.0000
# 1                 18.8323   760.6640       82.791           425.7290
# 2                  6.8704   120.9840        6.187            44.1020
# 3               6237.4090    20.6192          NaN             0.0775
# 4                  7.1948  5085.7240      210.139          1450.5610
#
#    Stock_minus_BasedCompensation  TotalAssets  TotalChangeInAssetsLiabilities  \
# 0                            1.0    7150.0000                         -47.000
# 1                            NaN     845.8610                         -21.145
# 2                            NaN      79.9760                          -0.577
# 3                            NaN       4.9015                             NaN
# 4                            NaN    2605.4040                           7.578
#
#    TotalCommonAndPreferredStockDividendsPaid  TotalCurrentAssets  \
# 0                                        NaN           4649.0000
# 1                                     -5.800            368.1340
# 2                                        NaN             62.5800
# 3                                        NaN              4.9015
# 4                                    -15.516            943.3320
#
#    TotalCurrentLiabilities  TotalDepreciationAndAmortization_minus_CashFlow  \
# 0                 1771.000                                           48.000
# 1                  170.029                                            6.387
# 2                   31.109                                            0.317
# 3                    4.824                                              NaN
# 4                  488.424                                           26.160
#
#    TotalLiabilities  TotalLiabilitiesAndShareHoldersEquity  \
# 0          3382.000                              7150.0000
# 1           420.132                               845.8610
# 2            35.874                                79.9760
# 3             4.824                                 4.9015
# 4          1154.843                              2605.4040
#
#    TotalLongTermLiabilities  TotalLong_minus_TermAssets  \
# 0                  1611.000                    2501.000
# 1                   250.103                     477.727
# 2                     4.765                      17.396
# 3                       NaN                       0.000
# 4                   666.419                    1662.072
#
#    TotalNon_minus_CashItems  TotalNon_minus_OperatingIncomeExpense  \
# 0                    81.000                                20.0000
# 1                     6.442                                -2.4670
# 2                     0.413                                -0.1540
# 3                       NaN                                -0.3197
# 4                    11.265                                -2.1690
#
#   execution_date  close_0  close_sp500_0  stock_change_365  \
# 0     2005-06-30  15.5105     1191.32761          0.370982
# 1     2005-06-30  17.1400     1191.32761          0.434656
# 2     2005-06-30  15.9600     1191.32761          0.609649
# 3     2005-06-30  28.3500     1191.32761          0.301587
# 4     2005-06-30   7.3325     1191.32761          0.266280
#
#    stock_change_div_365  sp500_change_365  stock_change_730  \
# 0              0.370982          0.066209          0.772214
# 1              0.454055          0.066209          0.463244
# 2              0.609649          0.066209          2.131579
# 3              0.397531          0.066209          0.406702
# 4              0.284691          0.066209          0.273440
#
#    stock_change_div_730  sp500_change_730  stock_change__minus_120  \
# 0              0.772214           0.26191                 0.057341
# 1              0.502917           0.26191                 0.164527
# 2              2.131579           0.26191                 0.115288
# 3              0.616931           0.26191                -0.089947
# 4              0.311626           0.26191                 0.090692
#
#    stock_change_div__minus_120  sp500_change__minus_120  \
# 0                     0.057341                 0.015743
# 1                     0.155193                 0.015743
# 2                     0.115288                 0.015743
# 3                    -0.114286                 0.015743
# 4                     0.086260                 0.015743
#
#    stock_change__minus_365  stock_change_div__minus_365  \
# 0                 0.271937                     0.271937
# 1                 0.265169                     0.246499
# 2                -0.252506                    -0.252506
# 3                -0.126984                    -0.195062
# 4                 0.060348                     0.043812
#
#    sp500_change__minus_365  stock_change__minus_730  \
# 0                -0.042383                -0.135100
# 1                -0.042383                -0.305718
# 2                -0.042383                -0.855890
# 3                -0.042383                -0.198236
# 4                -0.042383                -0.181725
#
#    stock_change_div__minus_730  sp500_change__minus_730   std_730  \
# 0                    -0.135100                -0.175443  0.017009
# 1                    -0.342474                -0.175443  0.019777
# 2                    -0.855890                -0.175443  0.032433
# 3                    -0.330864                -0.175443  0.020231
# 4                    -0.213092                -0.175443  0.011038
#
#    std__minus_120  std__minus_365  std__minus_730   Market_cap  \
# 0        0.014371        0.020641        0.021253  7693.208066
# 1        0.019412        0.018817        0.019823  1275.216000
# 2        0.038554        0.048526        0.047308   100.069200
# 3        0.014353        0.013229        0.013333   253.250550
# 4        0.013076        0.014600        0.013114  4095.230580
#
#    n_finan_prev_year  Enterprisevalue  EBITDAEV    EBITEV  RevenueEV  \
# 0                1.0      8592.208066  0.040036  0.017690   0.564232
# 1                1.0      1632.726000  0.073832  0.058185   0.465886
# 2                1.0       124.640200  0.124197  0.114024   0.970666
# 3                1.0       253.173050  0.081443  0.081443   0.081443
# 4                1.0      5104.868580  0.104953  0.084455   0.996250
#
#    CashOnHandEV       PFCF         PE           PB      RDEV  WorkingCapital  \
# 0      0.288983  17.641606  18.464881     2.021149  0.081469       2878.0000
# 1      0.038354  69.902121  21.974359     2.934881       NaN        198.1050
# 2      0.090685  10.511064   8.312500     2.235732       NaN         31.4710
# 3      0.019360        NaN  13.125000  3258.620690       NaN          0.0775
# 4      0.028444  17.293632  15.940218     2.793865       NaN        454.9080
#
#         ROC  DividendYieldLastYear  EPS_minus_EarningsPerShare_change_1_years  \
# 0  0.036956               0.000000                                        NaN
# 1  0.305831              -0.018670                                        NaN
# 2  0.355211               0.000000                                        NaN
# 3       NaN              -0.068078                                        NaN
# 4  0.338765              -0.016536                                        NaN
#
#    EPS_minus_EarningsPerShare_change_2_years  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    FreeCashFlowPerShare_change_1_years  FreeCashFlowPerShare_change_2_years  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    OperatingCashFlowPerShare_change_1_years  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    OperatingCashFlowPerShare_change_2_years  EBITDA_change_1_years  \
# 0                                       NaN                    NaN
# 1                                       NaN                    NaN
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
#
#    EBITDA_change_2_years  EBIT_change_1_years  EBIT_change_2_years  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
#
#    Revenue_change_1_years  Revenue_change_2_years  NetCashFlow_change_1_years  \
# 0                     NaN                     NaN                         NaN
# 1                     NaN                     NaN                         NaN
# 2                     NaN                     NaN                         NaN
# 3                     NaN                     NaN                         NaN
# 4                     NaN                     NaN                         NaN
#
#    NetCashFlow_change_2_years  CurrentRatio_change_1_years  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    CurrentRatio_change_2_years  Market_cap__minus_365  Market_cap__minus_730  \
# 0                          NaN                    NaN                    NaN
# 1                          NaN                    NaN                    NaN
# 2                          NaN                    NaN                    NaN
# 3                          NaN                    NaN                    NaN
# 4                          NaN                    NaN                    NaN
#
#    diff_ch_sp500  count  target
# 0       0.304773   1962     1.0
# 1       0.387846   1962     1.0
# 2       0.543440   1962     1.0
# 3       0.331322   1962     1.0
# 4       0.218482   1962     1.0

# %%
execution_dates = data_set.sort_values("execution_date")["execution_date"].unique()
execution_dates[-n_train_quarters:]
# Out:
# <DatetimeArray>
# ['2012-06-30 00:00:00', '2012-09-30 00:00:00', '2012-12-30 00:00:00',
#  '2013-03-31 00:00:00', '2013-06-30 00:00:00', '2013-09-30 00:00:00',
#  '2013-12-30 00:00:00', '2014-03-31 00:00:00', '2014-06-30 00:00:00',
#  '2014-09-30 00:00:00', '2014-12-30 00:00:00', '2015-03-31 00:00:00',
#  '2015-06-30 00:00:00', '2015-09-30 00:00:00', '2015-12-30 00:00:00',
#  '2016-03-31 00:00:00', '2016-06-30 00:00:00', '2016-09-30 00:00:00',
#  '2016-12-30 00:00:00', '2017-03-31 00:00:00', '2017-06-30 00:00:00',
#  '2017-09-30 00:00:00', '2017-12-30 00:00:00', '2018-03-31 00:00:00',
#  '2018-06-30 00:00:00', '2018-09-30 00:00:00', '2018-12-30 00:00:00',
#  '2019-03-31 00:00:00', '2019-06-30 00:00:00', '2019-09-30 00:00:00',
#  '2019-12-30 00:00:00', '2020-03-31 00:00:00', '2020-06-30 00:00:00',
#  '2020-09-30 00:00:00', '2020-12-30 00:00:00', '2021-03-27 00:00:00']
# Length: 36, dtype: datetime64[ns]

# %%
data_set.sort_values("execution_date")["execution_date"].value_counts()
# Out:
# execution_date
# 2020-12-30    3720
# 2020-09-30    3651
# 2020-06-30    3536
# 2020-03-31    3535
# 2019-09-30    3482
#               ...
# 2006-06-30    2052
# 2006-03-31    2036
# 2005-12-30    2005
# 2005-09-30    1992
# 2005-06-30    1962
# Name: count, Length: 64, dtype: int64

# %%
def split_train_test_by_period(data_set, test_execution_date,include_nulls_in_test = False):
    # we train with everything happening at least one year before the test execution date
    train_set = data_set.loc[data_set["execution_date"] <= pd.to_datetime(test_execution_date) - pd.Timedelta(350, unit = "day")]
    # remove those rows where the target is null
    train_set = train_set[~pd.isna(train_set["diff_ch_sp500"])]
    execution_dates = train_set.sort_values("execution_date")["execution_date"].unique()
    # Pick only the last n_train_quarters
    if n_train_quarters!=None:
        train_set = train_set[train_set["execution_date"].isin(execution_dates[-n_train_quarters:])]
        
    # the test set are the rows happening in the execution date with the concrete frequency
    test_set = data_set.loc[(data_set["execution_date"] == test_execution_date)]
    if not include_nulls_in_test:
        test_set = test_set[~pd.isna(test_set["diff_ch_sp500"])]
    test_set = test_set.sort_values('date', ascending = False).drop_duplicates('Ticker', keep = 'first')
    
    return train_set, test_set

# %% [markdown]
# Ensure that we don't include features which are irrelevant or related to the target:

# %%
def get_columns_to_remove():
    columns_to_remove = [
                         "date",
                         "improve_sp500",
                         "Ticker",
                         "freq",
                         "set",
                         "close_sp500_365",
                         "close_365",
                         "stock_change_365",
                         "sp500_change_365",
                         "stock_change_div_365",
                         "stock_change_730",
                         "sp500_change_365",
                         "stock_change_div_730",
                         "diff_ch_sp500",
                         "diff_ch_avg_500",
                         "execution_date","target","index","quarter","std_730","count"]
        
    return columns_to_remove

# %% [markdown]
# This is the main modeling function, it receives a train test and a test set and trains a `lightgbm` in classification mode. We don't recommend to change the main algorithm for this excercise but we suggest to play with its hyperparameters:

# %%
import warnings
warnings.filterwarnings('ignore')

def train_model(train_set,test_set,learning_rate,path_smooth,n_estimators = 300):

    columns_to_remove = get_columns_to_remove()
    
    X_train = train_set.drop(columns = columns_to_remove, errors = "ignore")
    X_test = test_set.drop(columns = columns_to_remove, errors = "ignore")
    
    
    y_train = train_set["target"]
    y_test = test_set["target"]

    lgb_train = lgb.Dataset(X_train,y_train)
    lgb_test = lgb.Dataset(X_test, y_test, reference=lgb_train)
    
    eval_result = {}
    
 
    objective = 'binary'
    metric = 'binary_logloss' 
    params = {
             "random_state":1, 
             "verbosity": -1,
             "n_jobs":10,
             "path_smooth": path_smooth,
             "learning_rate":learning_rate,
             "n_estimators":n_estimators,
             "objective": objective,
             "metric": metric}
    
    model = lgb.train(params = params,train_set = lgb_train,
                      valid_sets = [lgb_test,lgb_train],
                      feval = [top_wt_performance],
                      callbacks = [lgb.record_evaluation(eval_result = eval_result)])
    return model,eval_result,X_train,X_test

# %% [markdown]
# This is the function which receives an `execution_date` and splits the dataset between train and test, trains the models and evaluates the model in test. It returns a dictionary with the different evaluation metrics in train and test:

# %%
def run_model_for_execution_date(execution_date,all_results,all_predicted_tickers_list,all_models,n_estimators,learning_rate = 0.1,path_smooth = 0, include_nulls_in_test = False):
        global train_set
        global test_set
        # split the dataset between train and test
        train_set, test_set = split_train_test_by_period(data_set,execution_date,include_nulls_in_test = include_nulls_in_test)
        train_size, _ = train_set.shape
        test_size, _ = test_set.shape
        model = None
        X_train = None
        X_test = None
        
        # if both train and test are not empty
        if train_size > 0 and test_size>0:
            model, evals_result, X_train, X_test = train_model(train_set,
                                                              test_set,
                                                              learning_rate,
                                                              path_smooth,
                                                              n_estimators)
            
            test_set['prob'] = model.predict(X_test)
            predicted_tickers = test_set.sort_values('prob', ascending = False)
            predicted_tickers["execution_date"] = execution_date
            all_results[(execution_date)] = evals_result
            all_models[(execution_date)] = model
            all_predicted_tickers_list.append(predicted_tickers)
        return all_results,all_predicted_tickers_list,all_models,model,X_train,X_test


execution_dates = np.sort( data_set['execution_date'].unique() )

# %% [markdown]
# This is the main training loop: it goes through each different `execution_date` and calls `run_model_for_execution_date`. All the results are stored in `all_results` and the predictions in `all_predicted_tickers_list`.

# %%
all_results = {}
all_predicted_tickers_list = []
all_models = {}

for execution_date in execution_dates:
    print(execution_date)
    all_results,all_predicted_tickers_list,all_models,model,X_train,X_test = run_model_for_execution_date(execution_date,all_results,all_predicted_tickers_list,all_models,n_trees,include_nulls_in_test=False)
all_predicted_tickers = pd.concat(all_predicted_tickers_list)
# Out:
# 2005-06-30T00:00:00.000000000
# 2005-09-30T00:00:00.000000000
# 2005-12-30T00:00:00.000000000
# 2006-03-31T00:00:00.000000000
# 2006-06-30T00:00:00.000000000
# 2006-09-30T00:00:00.000000000
# 2006-12-30T00:00:00.000000000
# 2007-03-31T00:00:00.000000000
# 2007-06-30T00:00:00.000000000
# 2007-09-30T00:00:00.000000000
# 2007-12-30T00:00:00.000000000
# 2008-03-31T00:00:00.000000000
# 2008-06-30T00:00:00.000000000
# 2008-09-30T00:00:00.000000000
# 2008-12-30T00:00:00.000000000
# 2009-03-31T00:00:00.000000000
# 2009-06-30T00:00:00.000000000
# 2009-09-30T00:00:00.000000000
# 2009-12-30T00:00:00.000000000
# 2010-03-31T00:00:00.000000000
# 2010-06-30T00:00:00.000000000
# 2010-09-30T00:00:00.000000000
# 2010-12-30T00:00:00.000000000
# 2011-03-31T00:00:00.000000000
# 2011-06-30T00:00:00.000000000
# 2011-09-30T00:00:00.000000000
# 2011-12-30T00:00:00.000000000
# 2012-03-31T00:00:00.000000000
# 2012-06-30T00:00:00.000000000
# 2012-09-30T00:00:00.000000000
# 2012-12-30T00:00:00.000000000
# 2013-03-31T00:00:00.000000000
# 2013-06-30T00:00:00.000000000
# 2013-09-30T00:00:00.000000000
# 2013-12-30T00:00:00.000000000
# 2014-03-31T00:00:00.000000000
# 2014-06-30T00:00:00.000000000
# 2014-09-30T00:00:00.000000000
# 2014-12-30T00:00:00.000000000
# 2015-03-31T00:00:00.000000000
# 2015-06-30T00:00:00.000000000
# 2015-09-30T00:00:00.000000000
# 2015-12-30T00:00:00.000000000
# 2016-03-31T00:00:00.000000000
# 2016-06-30T00:00:00.000000000
# 2016-09-30T00:00:00.000000000
# 2016-12-30T00:00:00.000000000
# 2017-03-31T00:00:00.000000000
# 2017-06-30T00:00:00.000000000
# 2017-09-30T00:00:00.000000000
# 2017-12-30T00:00:00.000000000
# 2018-03-31T00:00:00.000000000
# 2018-06-30T00:00:00.000000000
# 2018-09-30T00:00:00.000000000
# 2018-12-30T00:00:00.000000000
# 2019-03-31T00:00:00.000000000
# 2019-06-30T00:00:00.000000000
# 2019-09-30T00:00:00.000000000
# 2019-12-30T00:00:00.000000000
# 2020-03-31T00:00:00.000000000
# 2020-06-30T00:00:00.000000000
# 2020-09-30T00:00:00.000000000
# 2020-12-30T00:00:00.000000000
# 2021-03-27T00:00:00.000000000

# %%
def parse_results_into_df(set_):
    df = pd.DataFrame()
    for date in all_results:
        df_tmp = pd.DataFrame(all_results[(date)][set_])
        df_tmp["n_trees"] = list(range(len(df_tmp)))
        df_tmp["execution_date"] = date
        df= pd.concat([df,df_tmp])
    
    df["execution_date"] = df["execution_date"].astype(str)
    
    return df

# %%
test_results = parse_results_into_df("valid_0")
train_results = parse_results_into_df("training")

# %%
test_results_final_tree = test_results.sort_values(["execution_date","n_trees"]).drop_duplicates("execution_date",keep = "last")
train_results_final_tree = train_results.sort_values(["execution_date","n_trees"]).drop_duplicates("execution_date",keep = "last")

# %% [markdown]
# And this are the results:

# %%
ggplot(test_results_final_tree) + geom_point(aes(x = "execution_date", y = "weighted-return")) + theme(axis_text_x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot(train_results_final_tree) + geom_point(aes(x = "execution_date", y = "weighted-return")) + theme(axis_text_x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# We have trained the first models for all the periods for you, but there are a lot of things which may be wrong or can be improved. Some ideas where you can start:
# * Try to see if there is any kind of data leakage or suspicious features
# * If the training part is very slow, try to see how you can modify it to execute faster tests
# * Try to understand if the algorithm is learning correctly
# * We are using a very high level metric to evaluate the algorithm so you maybe need to use some more low level ones
# * Try to see if there is overfitting
# * Try to see if there is a lot of noise between different trainings
# * To simplify, why if you only keep the first tickers in terms of Market Cap?
# * Change the number of quarters to train in the past

# %% [markdown]
# This function can be useful to compute the feature importance:

# %%
def draw_feature_importance(model,top = 15):
    fi = model.feature_importance()
    fn = model.feature_name()
    feature_importance = pd.DataFrame([{"feature":fn[i],"imp":fi[i]} for i in range(len(fi))])
    feature_importance = feature_importance.sort_values("imp",ascending = False).head(top)
    feature_importance = feature_importance.sort_values("imp",ascending = True)
    plot = ggplot(feature_importance,aes(x = "feature",y  = "imp")) + geom_col(fill = "lightblue") + coord_flip() +  scale_x_discrete(limits = feature_importance["feature"])
    return plot

# %%
from scipy.stats import lognorm
import matplotlib.pyplot as plt

# %%
all_predicted_tickers.head()
# Out:
#      Ticker       date  AssetTurnover  CashFlowFromFinancialActivities  \
# 8051     TD 2006-01-31         0.0105                          8049.80
# 8085     RY 2006-01-31         0.0122                         13705.14
# 8177     GS 2006-02-28         0.0137                         16873.00
# 9460    JPM 2006-03-31         0.0113                         53821.00
# 9370  RUSHB 2006-03-31         0.5860                            -9.08
#
#       CashFlowFromInvestingActivities  CashFlowFromOperatingActivities  \
# 8051                         -952.120                        -6645.170
# 8085                       -10458.820                        -3469.990
# 8177                         -920.000                       -19643.000
# 9460                       -34501.000                       -19141.000
# 9370                          -30.061                           27.377
#
#       CashOnHand  ChangeInAccountsPayable  ChangeInAccountsReceivable  \
# 8051   97038.950                      NaN                         NaN
# 8085  126104.100                      NaN                         NaN
# 8177  363986.000                -5282.000                   -2400.000
# 9460  513228.000                      NaN                    -125.000
# 9370     121.305                    3.425                       9.754
#
#       ChangeInAssetsLiabilities  ChangeInInventories  \
# 8051                        NaN                  NaN
# 8085                        NaN                  NaN
# 8177                   -313.000           -14689.000
# 9460                  -9752.000            -9330.000
# 9370                      0.189               -6.348
#
#       CommonStockDividendsPaid  CommonStockNet  ComprehensiveIncome  \
# 8051                       NaN        5154.850                  NaN
# 8085                       NaN        6160.970                  NaN
# 8177                    -148.0           6.000                 15.0
# 9460                   -1215.0        3645.000              -1017.0
# 9370                       NaN           0.248                  NaN
#
#       CostOfGoodsSold  CurrentRatio  DaysSalesInReceivables  \
# 8051         1871.680           NaN                     NaN
# 8085         2824.670           NaN                     NaN
# 8177          418.000        0.7275                721.3026
# 9460         8243.000           NaN                     NaN
# 9370          416.285        1.3010                  9.7096
#
#       DebtIssuanceRetirementNet_minus_Total  DebtEquityRatio       EBIT  \
# 8051                                  0.000           2.4956        NaN
# 8085                                  0.000           0.4011        NaN
# 8177                              18166.000          17.8806  9817.0000
# 9460                              29062.000           4.2880        NaN
# 9370                                -10.247           1.5966    90.6479
#
#       EBITMargin      EBITDA  EBITDAMargin  FinancialActivities_minus_Other  \
# 8051         NaN         NaN           NaN                         4285.000
# 8085         NaN         NaN           NaN                        14515.000
# 8177     35.3590  10692.0000           NaN                          788.000
# 9460         NaN         NaN           NaN                        27011.000
# 9370      4.4259    112.9829           NaN                            0.605
#
#       GoodwillAndIntangibleAssets  GrossMargin  GrossProfit  IncomeAfterTaxes  \
# 8051                      8270.90          NaN     4231.866          2008.800
# 8085                      4165.87          NaN     3707.380          1009.550
# 8177                          NaN      95.9935    10015.000          2479.000
# 9460                     59513.00          NaN    15175.000          3027.000
# 9370                          NaN      16.3893       81.600            11.577
#
#       IncomeFromContinuousOperations  IncomeFromDiscontinuedOperations  \
# 8051                        1977.099                               0.0
# 8085                        1002.690                               0.0
# 8177                        2479.000                               NaN
# 9460                        3027.000                              54.0
# 9370                          11.577                               NaN
#
#       IncomeTaxes  Inventory  InventoryTurnoverRatio  \
# 8051      188.540        NaN                     NaN
# 8085      284.520        NaN                     NaN
# 8177     1210.000        NaN                     NaN
# 9460     1537.000        NaN                     NaN
# 9370        6.946    355.626                  1.1706
#
#       InvestingActivities_minus_Other  LongTermDebt  \
# 8051                          730.160      6191.820
# 8085                        -8798.810      6955.410
# 8177                              NaN    114651.000
# 9460                        -5368.000    137513.000
# 9370                           -0.268       125.721
#
#       Long_minus_TermInvestments  Long_minus_termDebtCapital  \
# 8051                    42595.47                      0.2812
# 8085                    29229.69                      0.2863
# 8177                   292278.00                      0.7986
# 9460                   166905.00                      0.5593
# 9370                         NaN                      0.3044
#
#       NetAcquisitionsDivestitures  NetCashFlow  NetChangeInIntangibleAssets  \
# 8051                     -701.880      385.200                          NaN
# 8085                     -149.110      318.860                          NaN
# 8177                     -270.000     1040.000                          NaN
# 9460                     -663.000     -690.000                          NaN
# 9370                      -21.986       23.028                          NaN
#
#       NetChangeInInvestments_minus_Total  \
# 8051                             -916.13
# 8085                            -1409.76
# 8177                                 NaN
# 9460                           -28470.00
# 9370                                 NaN
#
#       NetChangeInLong_minus_TermInvestments  \
# 8051                                    NaN
# 8085                                    NaN
# 8177                                    NaN
# 9460                               -20101.0
# 9370                                    NaN
#
#       NetChangeInPropertyPlantAndEquipment  \
# 8051                               -64.270
# 8085                              -101.120
# 8177                              -650.000
# 9460                                   NaN
# 9370                                -7.807
#
#       NetChangeInShort_minus_termInvestments  \
# 8051                                     NaN
# 8085                                     NaN
# 8177                                     NaN
# 9460                                 -8369.0
# 9370                                     NaN
#
#       NetCommonEquityIssuedRepurchased  NetCurrentDebt  NetIncome  \
# 8051                               NaN        3541.120   1977.099
# 8085                               NaN        -271.660   1002.690
# 8177                         -1933.000        3938.000   2453.000
# 9460                          -898.000       26024.000   3077.000
# 9370                             0.562          -8.466     11.577
#
#       NetIncomeLoss  NetLong_minus_TermDebt  NetProfitMargin  \
# 8051       1977.090                     NaN          56.9069
# 8085       1004.400                     NaN          19.6705
# 8177       2479.000               14228.000          23.5119
# 9460       3081.000                3038.000          21.4515
# 9370         11.577                  -1.781           2.3252
#
#       NetTotalEquityIssuedRepurchased  OperatingExpenses  OperatingIncome  \
# 8051                          485.060           3931.900         2171.646
# 8085                         -117.400           5237.970         1294.080
# 8177                        -1933.000           6744.000         3689.000
# 9460                        -1037.000          18783.000         4635.000
# 9370                            0.562            475.849           22.036
#
#       OperatingMargin  OtherCurrentAssets  OtherIncome  \
# 8051              NaN                 NaN          NaN
# 8085              NaN                 NaN          NaN
# 8177          35.3590                 NaN          NaN
# 9460              NaN                 NaN          NaN
# 9370           4.4259                 NaN          NaN
#
#       OtherLong_minus_TermAssets  OtherNon_minus_CashItems  \
# 8051                   47248.120                       NaN
# 8085                   91927.800                    11.140
# 8177                   18942.000                   343.000
# 9460                   78188.000                  2256.000
# 9370                     112.591                     1.334
#
#       OtherNon_minus_CurrentLiabilities  OtherOperatingIncomeOrExpenses  \
# 8051                            16314.7                             NaN
# 8085                           114354.6                             NaN
# 8177                                NaN                          -327.0
# 9460                                NaN                             NaN
# 9370                                NaN                             NaN
#
#       OtherShareHoldersEquity  Pre_minus_PaidExpenses  Pre_minus_TaxIncome  \
# 8051                  -570.76                     NaN             2197.340
# 8085                 -1743.99                     NaN             1294.070
# 8177                  3305.00                     NaN             3689.000
# 9460                      NaN                     NaN             4564.000
# 9370                      NaN                    1.64               18.523
#
#       Pre_minus_TaxProfitMargin  PropertyPlantAndEquipment  \
# 8051                    63.2461                        NaN
# 8085                    25.3867                        NaN
# 8177                    35.3590                        NaN
# 9460                    31.8182                   8985.000
# 9370                     3.7203                    200.525
#
#       ROA_minus_ReturnOnAssets  ROE_minus_ReturnOnEquity  \
# 8051                    0.6002                   12.7826
# 8085                    0.2398                    5.9883
# 8177                    0.3267                    9.1257
# 9460                    0.2377                    2.7941
# 9370                    1.3626                    4.0292
#
#       ROI_minus_ReturnOnInvestment  Receivables  ReceiveableTurnover  \
# 8051                        8.9774          NaN                  NaN
# 8085                        4.1268          NaN                  NaN
# 8177                        1.7267    83615.000               0.1248
# 9460                        1.2312          NaN                  NaN
# 9370                        2.8028       53.714               9.2692
#
#       ResearchAndDevelopmentExpenses  RetainedEarningsAccumulatedDeficit  \
# 8051                             NaN                           10842.760
# 8085                             NaN                           12241.380
# 8177                           396.0                           21416.000
# 9460                             NaN                           35892.000
# 9370                             NaN                             122.347
#
#       ReturnOnTangibleEquity    Revenue  SGAExpenses  ShareHolderEquity  \
# 8051                 26.1504  18000.780     1682.290           15831.36
# 8085                  7.6102  23758.959     2401.310           17341.39
# 8177                  8.5734  29266.000     5740.000           28915.00
# 9460                  6.1998  84132.000    10185.000          108337.00
# 9370                  4.0292   1960.612       56.656             287.33
#
#       Stock_minus_BasedCompensation  TotalAssets  \
# 8051                            NaN   329411.100
# 8085                            NaN   418108.000
# 8177                        343.000   758821.000
# 9460                        839.000  1273282.000
# 9370                          0.964      849.621
#
#       TotalChangeInAssetsLiabilities  \
# 8051                       -7594.730
# 8085                       -4596.940
# 8177                      -22684.000
# 9460                      -25537.000
# 9370                           8.448
#
#       TotalCommonAndPreferredStockDividendsPaid  TotalCurrentAssets  \
# 8051                                    -261.38          229838.800
# 8085                                    -420.78          291296.800
# 8177                                    -148.00          447601.000
# 9460                                   -1215.00          959691.000
# 9370                                        NaN             536.505
#
#       TotalCurrentLiabilities  \
# 8051               288633.300
# 8085               276659.300
# 8177               615255.000
# 9460               985195.000
# 9370                  412.367
#
#       TotalDepreciationAndAmortization_minus_CashFlow  TotalLiabilities  \
# 8051                                          182.540        313579.700
# 8085                                           95.980        400766.600
# 8177                                          219.000        729906.000
# 9460                                          837.000       1164945.000
# 9370                                            6.018           562.291
#
#       TotalLiabilitiesAndShareHoldersEquity  TotalLongTermLiabilities  \
# 8051                             329411.100                 24946.390
# 8085                             418108.000                124107.300
# 8177                             758821.000                114651.000
# 9460                            1273282.000                179750.000
# 9370                                849.621                   149.924
#
#       TotalLong_minus_TermAssets  TotalNon_minus_CashItems  \
# 8051                   98114.480                   182.540
# 8085                  125323.400                   107.120
# 8177                  311220.000                   562.000
# 9460                  313591.000                  3093.000
# 9370                     313.116                     7.352
#
#       TotalNon_minus_OperatingIncomeExpense execution_date     close_0  \
# 8051                                    NaN     2006-06-30   25.483320
# 8085                                    NaN     2006-06-30   40.751731
# 8177                                    NaN     2006-06-30  150.430000
# 9460                                -71.000     2006-06-30   42.000000
# 9370                                 -3.513     2006-06-30    7.511111
#
#       close_sp500_0  stock_change_365  stock_change_div_365  sp500_change_365  \
# 8051     1270.20438          0.343890              0.373124          0.183549
# 8085     1270.20438          0.306123              0.345876          0.183549
# 8177     1270.20438          0.440870              0.450176          0.183549
# 9460     1270.20438          0.153571              0.185952          0.183549
# 9370     1270.20438          0.239053              0.239053          0.183549
#
#       stock_change_730  stock_change_div_730  sp500_change_730  \
# 8051          0.242549              0.316127          0.007713
# 8085          0.108486              0.196335          0.007713
# 8177          0.162667              0.181280          0.007713
# 9460         -0.183095             -0.114524          0.007713
# 9370         -0.036095             -0.036095          0.007713
#
#       stock_change__minus_120  stock_change_div__minus_120  \
# 8051                 0.132029                     0.114763
# 8085                 0.028775                     0.019941
# 8177                -0.042744                    -0.045071
# 9460                -0.008095                    -0.016190
# 9370                 0.035503                     0.035503
#
#       sp500_change__minus_120  stock_change__minus_365  \
# 8051                 0.014908                -0.124695
# 8085                 0.014908                -0.239673
# 8177                 0.014908                -0.321811
# 9460                 0.014908                -0.159048
# 9370                 0.014908                -0.206509
#
#       stock_change_div__minus_365  sp500_change__minus_365  \
# 8051                    -0.158442                -0.062098
# 8085                    -0.271696                -0.062098
# 8177                    -0.329123                -0.062098
# 9460                    -0.191429                -0.062098
# 9370                    -0.206509                -0.062098
#
#       stock_change__minus_730  stock_change_div__minus_730  \
# 8051                -0.372490                    -0.436061
# 8085                -0.458892                    -0.517172
# 8177                -0.374061                    -0.388021
# 9460                -0.076905                    -0.141667
# 9370                -0.233136                    -0.233136
#
#       sp500_change__minus_730   std_730  std__minus_120  std__minus_365  \
# 8051                -0.101849  0.013489        0.011074        0.009943
# 8085                -0.101849  0.013912        0.012474        0.011025
# 8177                -0.101849  0.022554        0.017813        0.013878
# 9460                -0.101849  0.020474        0.012135        0.010052
# 9370                -0.101849  0.025671        0.024161        0.020176
#
#       std__minus_730     Market_cap  n_finan_prev_year  Enterprisevalue  \
# 8051        0.009740   36619.530618                4.0    253160.280618
# 8085        0.011109   53572.470030                4.0    328234.970030
# 8177        0.012802   72702.819000                4.0    438622.819000
# 9460        0.009992  149973.600000                4.0    801690.600000
# 9370        0.022789     423.345000                4.0       864.331000
#
#       EBITDAEV    EBITEV  RevenueEV  CashOnHandEV       PFCF         PE  \
# 8051       NaN       NaN   0.071104      0.383310  10.072458  11.103843
# 8085       NaN       NaN   0.072384      0.384188  -2.567151  18.111880
# 8177  0.024376  0.022381   0.066722      0.829838  -2.672012  11.268165
# 9460       NaN       NaN   0.104943      0.640182  -3.951268  16.091954
# 9370  0.130717  0.104876   2.268358      0.140346 -26.559799   8.733850
#
#             PB      RDEV  WorkingCapital       ROC  DividendYieldLastYear  \
# 8051       NaN       NaN      -58794.500       NaN              -0.033748
# 8085       NaN       NaN       14637.500       NaN              -0.032023
# 8177  2.243627  0.000903     -167654.000       NaN              -0.007312
# 9460  1.346391       NaN      -25504.000       NaN              -0.032381
# 9370  1.450778       NaN         124.138  0.279206               0.000000
#
#       EPS_minus_EarningsPerShare_change_1_years  \
# 8051                                   0.490260
# 8085                                  -0.141221
# 8177                                   0.135204
# 9460                                   0.035714
# 9370                                   0.560232
#
#       EPS_minus_EarningsPerShare_change_2_years  \
# 8051                                        NaN
# 8085                                        NaN
# 8177                                        NaN
# 9460                                        NaN
# 9370                                        NaN
#
#       FreeCashFlowPerShare_change_1_years  \
# 8051                             1.136004
# 8085                             0.348613
# 8177                            -0.166129
# 9460                             0.177614
# 9370                             0.928744
#
#       FreeCashFlowPerShare_change_2_years  \
# 8051                                  NaN
# 8085                                  NaN
# 8177                                  NaN
# 9460                                  NaN
# 9370                                  NaN
#
#       OperatingCashFlowPerShare_change_1_years  \
# 8051                                  1.163775
# 8085                                  0.349572
# 8177                                 -0.226284
# 9460                                  0.177614
# 9370                                  1.119601
#
#       OperatingCashFlowPerShare_change_2_years  EBITDA_change_1_years  \
# 8051                                       NaN                    NaN
# 8085                                       NaN                    NaN
# 8177                                       NaN               0.140845
# 9460                                       NaN                    NaN
# 9370                                       NaN               0.439713
#
#       EBITDA_change_2_years  EBIT_change_1_years  EBIT_change_2_years  \
# 8051                    NaN                  NaN                  NaN
# 8085                    NaN                  NaN                  NaN
# 8177                    NaN             0.144172                  NaN
# 9460                    NaN                  NaN                  NaN
# 9370                    NaN             0.518289                  NaN
#
#       Revenue_change_1_years  Revenue_change_2_years  \
# 8051                0.265095                     NaN
# 8085                0.124467                     NaN
# 8177                0.142311                     NaN
# 9460                0.103863                     NaN
# 9370                0.219156                     NaN
#
#       NetCashFlow_change_1_years  NetCashFlow_change_2_years  \
# 8051                   -0.617174                         NaN
# 8085                   -0.838614                         NaN
# 8177                   -0.777015                         NaN
# 9460                   -1.071134                         NaN
# 9370                    1.096113                         NaN
#
#       CurrentRatio_change_1_years  CurrentRatio_change_2_years  \
# 8051                          NaN                          NaN
# 8085                          NaN                          NaN
# 8177                    -0.032194                          NaN
# 9460                          NaN                          NaN
# 9370                     0.045820                          NaN
#
#       Market_cap__minus_365  Market_cap__minus_730  diff_ch_sp500  count  \
# 8051           29528.262573                    NaN       0.189576   2052
# 8085           40256.249510                    NaN       0.162328   2052
# 8177           52550.502000                    NaN       0.266628   2052
# 9460          126085.336000                    NaN       0.002404   2052
# 9370             332.501248                    NaN       0.055505   2052
#
#       target      prob
# 8051     1.0  0.955844
# 8085     1.0  0.951718
# 8177     1.0  0.949645
# 9460     1.0  0.943300
# 9370     1.0  0.940366

# %%
data_set.sort_values("execution_date").head()
# Out:
#      Ticker       date  AssetTurnover  CashFlowFromFinancialActivities  \
# 0         A 2005-01-31         0.1695                           81.000
# 1315   HALL 2005-03-31         0.2181                            0.013
# 1314    SPH 2005-03-31         0.5592                           -1.539
# 1313   SRCE 2005-03-31         0.0125                         -227.878
# 1312   LCII 2005-03-31         0.5917                           -2.685
#
#       CashFlowFromInvestingActivities  CashFlowFromOperatingActivities  \
# 0                             -57.000                          137.000
# 1315                           -6.395                           -0.241
# 1314                          -12.944                          -22.096
# 1313                          241.424                           -4.846
# 1312                           -3.850                            9.654
#
#       CashOnHand  ChangeInAccountsPayable  ChangeInAccountsReceivable  \
# 0       2483.000                    5.000                      44.000
# 1315      12.758                    0.594                       0.848
# 1314      16.902                   13.547                     -99.511
# 1313     113.207                    0.099                     -24.176
# 1312       5.543                      NaN                     -15.936
#
#       ChangeInAssetsLiabilities  ChangeInInventories  \
# 0                        -5.000              -13.000
# 1315                     -2.659                  NaN
# 1314                      5.928               -3.292
# 1313                     -0.109                  NaN
# 1312                      0.681               -2.020
#
#       CommonStockDividendsPaid  CommonStockNet  ComprehensiveIncome  \
# 0                          NaN           5.000              215.000
# 1315                       NaN           1.106               -1.240
# 1314                     0.000         294.479              -75.651
# 1313                    -2.534           7.578               -4.241
# 1312                       NaN           0.229                0.230
#
#       CostOfGoodsSold  CurrentRatio  DaysSalesInReceivables  \
# 0             621.000        2.6251                 70.2475
# 1315            6.026           NaN                     NaN
# 1314          380.515        1.5110                 29.1912
# 1313           15.192           NaN                     NaN
# 1312          121.528        2.0142                 24.4791
#
#       DebtIssuanceRetirementNet_minus_Total  DebtEquityRatio     EBIT  \
# 0                                    23.000           0.3052  152.000
# 1315                                    NaN              NaN   10.828
# 1314                                 38.000           2.5976  300.280
# 1313                                 -7.797           1.1288      NaN
# 1312                                 -3.594           0.5238   41.772
#
#       EBITMargin   EBITDA  EBITDAMargin  FinancialActivities_minus_Other  \
# 0         3.1353  344.000           NaN                              NaN
# 1315     15.5173   11.116           NaN                              NaN
# 1314     12.7807  338.736           NaN                          -39.539
# 1313         NaN      NaN           NaN                         -217.064
# 1312      6.7572   52.068           NaN                           -0.229
#
#       GoodwillAndIntangibleAssets  GrossMargin  GrossProfit  IncomeAfterTaxes  \
# 0                         459.000      48.7624      591.000            43.000
# 1315                        5.315          NaN       11.419             1.815
# 1314                      305.545      35.2170      206.854            64.481
# 1313                          NaN          NaN       41.299             6.944
# 1312                       21.702      21.3645       33.018             5.816
#
#       IncomeFromContinuousOperations  IncomeFromDiscontinuedOperations  \
# 0                             51.000                            52.000
# 1315                           1.815                               NaN
# 1314                          64.481                             0.976
# 1313                           6.944                               NaN
# 1312                           5.816                               NaN
#
#       IncomeTaxes  Inventory  InventoryTurnoverRatio  \
# 0          15.000   1037.000                  0.5988
# 1315        0.889        NaN                     NaN
# 1314        0.109     67.433                  5.6429
# 1313        3.102        NaN                     NaN
# 1312        3.683     74.352                  1.6345
#
#       InvestingActivities_minus_Other  LongTermDebt  \
# 0                              -9.000      1150.000
# 1315                            0.029           NaN
# 1314                            0.000       515.475
# 1313                            0.569        77.049
# 1312                           -0.036        63.870
#
#       Long_minus_TermInvestments  Long_minus_termDebtCapital  \
# 0                            NaN                      0.2338
# 1315                      37.726                         NaN
# 1314                         NaN                      0.7074
# 1313                     733.786                      0.1909
# 1312                         NaN                      0.3303
#
#       NetAcquisitionsDivestitures  NetCashFlow  NetChangeInIntangibleAssets  \
# 0                         -10.000      672.000                          NaN
# 1315                          NaN      -26.492                          NaN
# 1314                        0.000     -146.316                          0.0
# 1313                          NaN       34.800                          NaN
# 1312                        0.694       12.476                          NaN
#
#       NetChangeInInvestments_minus_Total  \
# 0                                -10.000
# 1315                              -6.372
# 1314                               0.000
# 1313                             243.137
# 1312                                 NaN
#
#       NetChangeInLong_minus_TermInvestments  \
# 0                                   -10.000
# 1315                                 -5.075
# 1314                                  0.000
# 1313                                 49.258
# 1312                                    NaN
#
#       NetChangeInPropertyPlantAndEquipment  \
# 0                                  -28.000
# 1315                                -0.052
# 1314                               -12.944
# 1313                                -2.282
# 1312                                -4.508
#
#       NetChangeInShort_minus_termInvestments  \
# 0                                        NaN
# 1315                                  -1.297
# 1314                                   0.000
# 1313                                 193.879
# 1312                                     NaN
#
#       NetCommonEquityIssuedRepurchased  NetCurrentDebt  NetIncome  \
# 0                               58.000          23.000    103.000
# 1315                             0.013             NaN      1.815
# 1314                             0.000          38.000     65.457
# 1313                            -0.483          -8.014      6.944
# 1312                             1.138          -3.594      5.816
#
#       NetIncomeLoss  NetLong_minus_TermDebt  NetProfitMargin  \
# 0           103.000                     NaN           8.4984
# 1315          1.815                     NaN          10.4041
# 1314         90.358                   0.000          11.1441
# 1313          6.944                   0.217          16.6443
# 1312          5.816                     NaN           3.7633
#
#       NetTotalEquityIssuedRepurchased  OperatingExpenses  OperatingIncome  \
# 0                              58.000           1174.000           38.000
# 1315                            0.013             14.741            2.704
# 1314                            0.000            512.299           75.070
# 1313                           -0.483             46.445           10.046
# 1312                            1.138            144.103           10.443
#
#       OperatingMargin  OtherCurrentAssets  OtherIncome  \
# 0              3.1353               183.0          NaN
# 1315          15.5002                 NaN          NaN
# 1314          12.7807                 NaN          NaN
# 1313              NaN                 NaN          NaN
# 1312           6.7572                 NaN          NaN
#
#       OtherLong_minus_TermAssets  OtherNon_minus_CashItems  \
# 0                        807.000                    33.000
# 1315                       2.483                     0.266
# 1314                      26.816                    -1.126
# 1313                      44.552                     4.593
# 1312                       6.366                    -0.621
#
#       OtherNon_minus_CurrentLiabilities  OtherOperatingIncomeOrExpenses  \
# 0                               461.000                             NaN
# 1315                              2.160                          -8.705
# 1314                             45.366                        -110.229
# 1313                                NaN                             NaN
# 1312                              2.317                           0.031
#
#       OtherShareHoldersEquity  Pre_minus_PaidExpenses  Pre_minus_TaxIncome  \
# 0                         NaN                     NaN               58.000
# 1315                      NaN                     NaN                2.704
# 1314                      NaN                  37.737               64.590
# 1313                      NaN                     NaN               10.046
# 1312                      NaN                   9.996                9.499
#
#       Pre_minus_TaxProfitMargin  PropertyPlantAndEquipment  \
# 0                        4.7855                   1235.000
# 1315                    15.5001                        NaN
# 1314                    10.9965                    405.423
# 1313                    24.0796                     37.581
# 1312                     6.1464                    101.184
#
#       ROA_minus_ReturnOnAssets  ROE_minus_ReturnOnEquity  \
# 0                       0.7133                    1.3535
# 1315                    2.2692                    5.3364
# 1314                    6.1389                   30.2387
# 1313                    0.2078                    2.1260
# 1312                    2.2268                    4.4914
#
#       ROI_minus_ReturnOnInvestment  Receivables  ReceiveableTurnover  \
# 0                           1.0370      946.000               1.2812
# 1315                        5.3364        8.686                  NaN
# 1314                        8.8486      190.511               3.0831
# 1313                        1.7202          NaN                  NaN
# 1312                        3.0078       42.035               3.6766
#
#       ResearchAndDevelopmentExpenses  RetainedEarningsAccumulatedDeficit  \
# 0                              700.0                           -1707.000
# 1315                             NaN                              14.918
# 1314                             NaN                                 NaN
# 1313                             NaN                             120.387
# 1312                             NaN                             111.229
#
#       ReturnOnTangibleEquity   Revenue  SGAExpenses  ShareHolderEquity  \
# 0                     1.5413  4848.000      378.000           3768.000
# 1315                  6.3247    69.780          NaN             34.012
# 1314                -69.8564  2349.476       12.057            213.240
# 1313                  2.1260   225.964       27.930            326.629
# 1312                  5.3956   618.184       22.606            129.493
#
#       Stock_minus_BasedCompensation  TotalAssets  \
# 0                             1.000     7150.000
# 1315                            NaN       79.985
# 1314                          0.917     1050.367
# 1313                            NaN     3341.453
# 1312                          0.324      261.178
#
#       TotalChangeInAssetsLiabilities  \
# 0                            -47.000
# 1315                          -2.394
# 1314                        -130.469
# 1313                         -24.186
# 1312                           1.885
#
#       TotalCommonAndPreferredStockDividendsPaid  TotalCurrentAssets  \
# 0                                           NaN            4649.000
# 1315                                        NaN              21.444
# 1314                                      0.000             312.583
# 1313                                     -2.534            2525.534
# 1312                                        NaN             131.926
#
#       TotalCurrentLiabilities  \
# 0                    1771.000
# 1315                   43.647
# 1314                  206.870
# 1313                 2937.775
# 1312                   65.498
#
#       TotalDepreciationAndAmortization_minus_CashFlow  TotalLiabilities  \
# 0                                              48.000          3382.000
# 1315                                            0.072            45.973
# 1314                                           19.141           837.127
# 1313                                            7.850          3014.824
# 1312                                            2.574           131.685
#
#       TotalLiabilitiesAndShareHoldersEquity  TotalLongTermLiabilities  \
# 0                                  7150.000                  1611.000
# 1315                                 79.985                     2.326
# 1314                               1050.367                   630.257
# 1313                               3341.453                    77.049
# 1312                                261.178                    66.187
#
#       TotalLong_minus_TermAssets  TotalNon_minus_CashItems  \
# 0                       2501.000                    81.000
# 1315                      58.541                     0.338
# 1314                     737.784                    18.015
# 1313                     815.919                    12.443
# 1312                     129.252                     1.953
#
#       TotalNon_minus_OperatingIncomeExpense execution_date   close_0  \
# 0                                    20.000     2005-06-30  15.51050
# 1315                                    NaN     2005-06-30   7.80000
# 1314                                -10.480     2005-06-30  35.78000
# 1313                                    NaN     2005-06-30  19.07438
# 1312                                 -0.944     2005-06-30  22.70000
#
#       close_sp500_0  stock_change_365  stock_change_div_365  sp500_change_365  \
# 0        1191.32761          0.370982              0.370982          0.066209
# 1315     1191.32761          0.453846              0.453846          0.066209
# 1314     1191.32761         -0.119061             -0.050587          0.066209
# 1313     1191.32761          0.465771              0.488735          0.066209
# 1312     1191.32761          0.427313              0.427313          0.066209
#
#       stock_change_730  stock_change_div_730  sp500_change_730  \
# 0             0.772214              0.772214           0.26191
# 1315          0.583333              0.583333           0.26191
# 1314          0.337898              0.481484           0.26191
# 1313          0.187695              0.237348           0.26191
# 1312          0.459912              0.459912           0.26191
#
#       stock_change__minus_120  stock_change_div__minus_120  \
# 0                    0.057341                     0.057341
# 1315                 0.038462                     0.038462
# 1314                -0.017608                    -0.034726
# 1313                 0.018631                     0.013432
# 1312                -0.175330                    -0.175330
#
#       sp500_change__minus_120  stock_change__minus_365  \
# 0                    0.015743                 0.271937
# 1315                 0.015743                -0.384615
# 1314                 0.015743                -0.100615
# 1313                 0.015743                 0.076690
# 1312                 0.015743                -0.103524
#
#       stock_change_div__minus_365  sp500_change__minus_365  \
# 0                        0.271937                -0.042383
# 1315                    -0.384615                -0.042383
# 1314                    -0.169089                -0.042383
# 1313                     0.056759                -0.042383
# 1312                    -0.103524                -0.042383
#
#       stock_change__minus_730  stock_change_div__minus_730  \
# 0                   -0.135100                    -0.135100
# 1315                -0.330769                    -0.330769
# 1314                -0.182504                    -0.317007
# 1313                -0.164211                    -0.201040
# 1312                -0.585463                    -0.585463
#
#       sp500_change__minus_730   std_730  std__minus_120  std__minus_365  \
# 0                   -0.175443  0.017009        0.014371        0.020641
# 1315                -0.175443  0.032514        0.054937        0.055970
# 1314                -0.175443  0.015028        0.008655        0.010048
# 1313                -0.175443  0.022165        0.022819        0.019679
# 1312                -0.175443  0.022472        0.013141        0.016019
#
#       std__minus_730   Market_cap  n_finan_prev_year  Enterprisevalue  \
# 0           0.021253  7693.208066                1.0      8592.208066
# 1315        0.060967    56.125680                1.0        89.340680
# 1314        0.011109  1087.890900                1.0      1908.115900
# 1313        0.021824   484.725768                1.0      3386.342768
# 1312        0.020320   484.054800                1.0       610.196800
#
#       EBITDAEV    EBITEV  RevenueEV  CashOnHandEV       PFCF         PE  \
# 0     0.040036  0.017690   0.564232      0.288983  17.641606  18.464881
# 1315  0.124423  0.121199   0.781055      0.142802 -47.911548   8.125000
# 1314  0.177524  0.157370   1.231307      0.008858  -7.762062   4.707895
# 1313       NaN       NaN   0.066728      0.033430 -17.000338  17.486597
# 1312  0.085330  0.068457   1.013090      0.009084  23.518442  21.018519
#
#             PB      RDEV  WorkingCapital       ROC  DividendYieldLastYear  \
# 0     2.021149  0.081469        2878.000  0.036956               0.000000
# 1315  1.395449       NaN         -22.203       NaN               0.000000
# 1314  5.080438       NaN         105.713  0.587476              -0.068474
# 1313  1.463320       NaN        -412.241       NaN              -0.019931
# 1312  3.632523       NaN          66.428  0.249218               0.000000
#
#       EPS_minus_EarningsPerShare_change_1_years  \
# 0                                           NaN
# 1315                                        NaN
# 1314                                        NaN
# 1313                                        NaN
# 1312                                        NaN
#
#       EPS_minus_EarningsPerShare_change_2_years  \
# 0                                           NaN
# 1315                                        NaN
# 1314                                        NaN
# 1313                                        NaN
# 1312                                        NaN
#
#       FreeCashFlowPerShare_change_1_years  \
# 0                                     NaN
# 1315                                  NaN
# 1314                                  NaN
# 1313                                  NaN
# 1312                                  NaN
#
#       FreeCashFlowPerShare_change_2_years  \
# 0                                     NaN
# 1315                                  NaN
# 1314                                  NaN
# 1313                                  NaN
# 1312                                  NaN
#
#       OperatingCashFlowPerShare_change_1_years  \
# 0                                          NaN
# 1315                                       NaN
# 1314                                       NaN
# 1313                                       NaN
# 1312                                       NaN
#
#       OperatingCashFlowPerShare_change_2_years  EBITDA_change_1_years  \
# 0                                          NaN                    NaN
# 1315                                       NaN                    NaN
# 1314                                       NaN                    NaN
# 1313                                       NaN                    NaN
# 1312                                       NaN                    NaN
#
#       EBITDA_change_2_years  EBIT_change_1_years  EBIT_change_2_years  \
# 0                       NaN                  NaN                  NaN
# 1315                    NaN                  NaN                  NaN
# 1314                    NaN                  NaN                  NaN
# 1313                    NaN                  NaN                  NaN
# 1312                    NaN                  NaN                  NaN
#
#       Revenue_change_1_years  Revenue_change_2_years  \
# 0                        NaN                     NaN
# 1315                     NaN                     NaN
# 1314                     NaN                     NaN
# 1313                     NaN                     NaN
# 1312                     NaN                     NaN
#
#       NetCashFlow_change_1_years  NetCashFlow_change_2_years  \
# 0                            NaN                         NaN
# 1315                         NaN                         NaN
# 1314                         NaN                         NaN
# 1313                         NaN                         NaN
# 1312                         NaN                         NaN
#
#       CurrentRatio_change_1_years  CurrentRatio_change_2_years  \
# 0                             NaN                          NaN
# 1315                          NaN                          NaN
# 1314                          NaN                          NaN
# 1313                          NaN                          NaN
# 1312                          NaN                          NaN
#
#       Market_cap__minus_365  Market_cap__minus_730  diff_ch_sp500  count  \
# 0                       NaN                    NaN       0.304773   1962
# 1315                    NaN                    NaN       0.387637   1962
# 1314                    NaN                    NaN      -0.116796   1962
# 1313                    NaN                    NaN       0.422526   1962
# 1312                    NaN                    NaN       0.361104   1962
#
#       target
# 0        1.0
# 1315     1.0
# 1314     0.0
# 1313     1.0
# 1312     1.0

# %% [markdown]
# ### BASELINE
# Our baseline is going to be the MarketCap at the exectuion_date. The top_n = 500 tickers with biggest MarketCap will be the selected ones

# %%
test_results_final_tree.head()
# Out:
#     binary_logloss  weighted-return  n_trees execution_date
# 39        0.759610         0.099404       39     2006-06-30
# 39        0.730303         0.035528       39     2006-09-30
# 39        0.715078        -0.052195       39     2006-12-30
# 39        0.710833        -0.067471       39     2007-03-31
# 39        0.711701        -0.045395       39     2007-06-30

# %%
def predict_baseline(all_predicted_tickers, top_n = 500):
    all_predicted_tickers_ordered = all_predicted_tickers.sort_values(['execution_date', 'Market_cap'], ascending=False)
    all_predicted_tickers_ordered['ranking'] = all_predicted_tickers.groupby('execution_date').cumcount()
    all_predicted_tickers_top_ranked = all_predicted_tickers_ordered[all_predicted_tickers_ordered['ranking'] <= top_n]
    baseline_preds =  all_predicted_tickers_top_ranked.groupby(['execution_date'])['diff_ch_sp500'].mean().reset_index()
    baseline_preds = baseline_preds.rename(columns={'diff_ch_sp500': 'baseline-preds'})
    baseline_preds['execution_date'] = baseline_preds['execution_date'].astype(str)
    return baseline_preds

# %%
baseline_predictions = predict_baseline(all_predicted_tickers)
merged_results = pd.merge(test_results_final_tree, baseline_predictions, on='execution_date')

# %%
merged_results.head()
# Out:
#    binary_logloss  weighted-return  n_trees execution_date  baseline-preds
# 0        0.759610         0.099404       39     2006-06-30        0.095930
# 1        0.730303         0.035528       39     2006-09-30        0.153771
# 2        0.715078        -0.052195       39     2006-12-30        0.071893
# 3        0.710833        -0.067471       39     2007-03-31        0.050403
# 4        0.711701        -0.045395       39     2007-06-30        0.072131

# %%
ggplot(merged_results[merged_results["weighted-return"] < 2], aes(x = "execution_date")) + geom_point(aes(y = "weighted-return"), colour = "blue") + geom_point(aes(y = "baseline-preds"), colour = "red") + theme(axis_text_x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# <Figure Size: (640 x 480)>

# %%
merged_results['baseline-preds'].mean()
# Out:
# 0.2854656198435846

# %%
merged_results[merged_results["weighted-return"] < 2]['weighted-return'].mean()
# Out:
# 0.1943824360350931

# %%
(merged_results["weighted-return"] > merged_results["baseline-preds"]).value_counts(normalize=True)
# Out:
# False    0.535714
# True     0.464286
# Name: proportion, dtype: float64

# %%
def calculate_learning_rate(set_):
    df = pd.DataFrame()
    for date in all_results:
        df_tmp = pd.DataFrame(all_results[(date)][set_])
        df_tmp["n_trees"] = list(range(len(df_tmp)))
        df_tmp["execution_date"] = date
        df= pd.concat([df,df_tmp])

    df['first_tree_metrics'] = df.groupby('execution_date')['binary_logloss'].transform('first')
    df[f'norm_learning_{set_}'] = (df['binary_logloss'] - df['first_tree_metrics']) / df['first_tree_metrics']
    df = df.drop(columns = 'first_tree_metrics')
    return df

# %%
learning_rates_train = calculate_learning_rate('training')
learning_rates_test = calculate_learning_rate('valid_0')

# %%
learning_rates_train['n_trees_cat_training'] = pd.Categorical(learning_rates_train['n_trees'], categories=sorted(learning_rates_train['n_trees'].unique()))
learning_rates_test['n_trees_cat_valid_0'] = pd.Categorical(learning_rates_test['n_trees'], categories=sorted(learning_rates_test['n_trees'].unique()))

# %%
learning_rates = pd.merge(learning_rates_test[['n_trees_cat_valid_0', 'norm_learning_valid_0', 'execution_date', 'n_trees']], learning_rates_train[['n_trees_cat_training', 'norm_learning_training', 'execution_date', 'n_trees']], on=['execution_date', 'n_trees'])

# %%
ggplot(learning_rates, aes(x = "n_trees_cat_training")) + geom_boxplot(aes(y = "norm_learning_training"))
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot(learning_rates[learning_rates['n_trees'] < 25], aes(x = "n_trees_cat_valid_0", y = 'norm_learning_valid_0')) + geom_boxplot()
# Out:
# <Figure Size: (640 x 480)>

# %%
all_results = {}
all_predicted_tickers_list = []
all_models = {}

for execution_date in execution_dates:
    print(execution_date)
    all_results,all_predicted_tickers_list,all_models,model,X_train,X_test = run_model_for_execution_date(execution_date,all_results,all_predicted_tickers_list,all_models,n_trees,10e-3,0.5,False)
all_predicted_tickers = pd.concat(all_predicted_tickers_list)
# Out:
# 2005-06-30T00:00:00.000000000
# 2005-09-30T00:00:00.000000000
# 2005-12-30T00:00:00.000000000
# 2006-03-31T00:00:00.000000000
# 2006-06-30T00:00:00.000000000
# 2006-09-30T00:00:00.000000000
# 2006-12-30T00:00:00.000000000
# 2007-03-31T00:00:00.000000000
# 2007-06-30T00:00:00.000000000
# 2007-09-30T00:00:00.000000000
# 2007-12-30T00:00:00.000000000
# 2008-03-31T00:00:00.000000000
# 2008-06-30T00:00:00.000000000
# 2008-09-30T00:00:00.000000000
# 2008-12-30T00:00:00.000000000
# 2009-03-31T00:00:00.000000000
# 2009-06-30T00:00:00.000000000
# 2009-09-30T00:00:00.000000000
# 2009-12-30T00:00:00.000000000
# 2010-03-31T00:00:00.000000000
# 2010-06-30T00:00:00.000000000
# 2010-09-30T00:00:00.000000000
# 2010-12-30T00:00:00.000000000
# 2011-03-31T00:00:00.000000000
# 2011-06-30T00:00:00.000000000
# 2011-09-30T00:00:00.000000000
# 2011-12-30T00:00:00.000000000
# 2012-03-31T00:00:00.000000000
# 2012-06-30T00:00:00.000000000
# 2012-09-30T00:00:00.000000000
# 2012-12-30T00:00:00.000000000
# 2013-03-31T00:00:00.000000000
# 2013-06-30T00:00:00.000000000
# 2013-09-30T00:00:00.000000000
# 2013-12-30T00:00:00.000000000
# 2014-03-31T00:00:00.000000000
# 2014-06-30T00:00:00.000000000
# 2014-09-30T00:00:00.000000000
# 2014-12-30T00:00:00.000000000
# 2015-03-31T00:00:00.000000000
# 2015-06-30T00:00:00.000000000
# 2015-09-30T00:00:00.000000000
# 2015-12-30T00:00:00.000000000
# 2016-03-31T00:00:00.000000000
# 2016-06-30T00:00:00.000000000
# 2016-09-30T00:00:00.000000000
# 2016-12-30T00:00:00.000000000
# 2017-03-31T00:00:00.000000000
# 2017-06-30T00:00:00.000000000
# 2017-09-30T00:00:00.000000000
# 2017-12-30T00:00:00.000000000
# 2018-03-31T00:00:00.000000000
# 2018-06-30T00:00:00.000000000
# 2018-09-30T00:00:00.000000000
# 2018-12-30T00:00:00.000000000
# 2019-03-31T00:00:00.000000000
# 2019-06-30T00:00:00.000000000
# 2019-09-30T00:00:00.000000000
# 2019-12-30T00:00:00.000000000
# 2020-03-31T00:00:00.000000000
# 2020-06-30T00:00:00.000000000
# 2020-09-30T00:00:00.000000000
# 2020-12-30T00:00:00.000000000
# 2021-03-27T00:00:00.000000000

# %%
learning_rates_train = calculate_learning_rate('training')
learning_rates_test = calculate_learning_rate('valid_0')

# %%
learning_rates_train['n_trees_cat_training'] = pd.Categorical(learning_rates_train['n_trees'], categories=sorted(learning_rates_train['n_trees'].unique()))
learning_rates_test['n_trees_cat_valid_0'] = pd.Categorical(learning_rates_test['n_trees'], categories=sorted(learning_rates_test['n_trees'].unique()))

# %%
learning_rates = pd.merge(learning_rates_test[['n_trees_cat_valid_0', 'norm_learning_valid_0', 'execution_date', 'n_trees']], learning_rates_train[['n_trees_cat_training', 'norm_learning_training', 'execution_date', 'n_trees']], on=['execution_date', 'n_trees'])

# %%
ggplot(learning_rates, aes(x = "n_trees_cat_training")) + geom_boxplot(aes(y = "norm_learning_training"))
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot(learning_rates, aes(x = "n_trees_cat_valid_0", y = 'norm_learning_valid_0')) + geom_boxplot()
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# ### FEATURE IMPORTANCE

# %%
params = {
             "random_state":1, 
             "verbosity": -1,
             "n_jobs":10,
             "path_smooth": 0.5,
             "learning_rate":10e-3,
             "n_estimators":n_trees,
             "objective": 'binary',
             "metric": 'binary_logloss'}

# %%
from sklearn.inspection import permutation_importance
from lightgbm import LGBMClassifier

def train_model_importance(train_set,test_set,params):

    columns_to_remove = get_columns_to_remove()
    
    X_train = train_set.drop(columns = columns_to_remove, errors = "ignore")
    X_test = test_set.drop(columns = columns_to_remove, errors = "ignore")
    
    
    y_train = train_set["target"]
    y_test = test_set["target"]

    clf = LGBMClassifier(**params)
    lgb_train = lgb.Dataset(X_train,y_train)
    lgb_test = lgb.Dataset(X_test, y_test, reference=lgb_train)
    
    eval_result = {}
 
    model = clf.fit(X_train, y_train,
                    eval_set = [(X_test, y_test), (X_train,y_train)],
                    eval_metric = [top_wt_performance],
                    callbacks = [lgb.record_evaluation(eval_result = eval_result)])

    pi = permutation_importance(model, X_test, y_test, n_repeats=20, random_state=0)
    feature_names = X_test.columns
    df_feature_importance = pd.DataFrame({'importance':pi.importances_mean, 'feature':feature_names})
    return model,eval_result,X_train,X_test,df_feature_importance

# %%
from sklearn.inspection import permutation_importance
from lightgbm import LGBMClassifier

def run_model_for_execution_date(execution_date,all_results,all_predicted_tickers_list,all_models,all_feature_importance,params):
        global train_set
        global test_set

        train_set, test_set = split_train_test_by_period(data_set,execution_date,include_nulls_in_test = False)
        train_size, _ = train_set.shape
        test_size, _ = test_set.shape
        model = None
        X_train = None
        X_test = None
        
        # if both train and test are not empty
        if train_size > 0 and test_size>0:
            model, evals_result, X_train, X_test, df_feature_importance = train_model_importance(train_set,
                                                                                                 test_set,
                                                                                                 params)
            
            test_set['prob'] = model.predict(X_test)
            predicted_tickers = test_set.sort_values('prob', ascending = False)
            predicted_tickers["execution_date"] = execution_date
            all_results[(execution_date)] = evals_result
            all_models[(execution_date)] = model
            all_predicted_tickers_list.append(predicted_tickers)
            df_feature_importance["execution_date"] = execution_date
            all_feature_importance = pd.concat([all_feature_importance, df_feature_importance])
        return all_results,all_predicted_tickers_list,all_models,all_feature_importance,model,X_train,X_test

# %%
period_frequency = 4 #We train each 4 quarters = each year
all_results = {}
all_predicted_tickers_list = []
all_models = {}
all_feature_importance = pd.DataFrame()
execution_dates = np.sort( data_set['execution_date'].unique() )

for i,execution_date in enumerate(execution_dates):
            if i%period_frequency == 0:
                print(execution_date)
                all_results,all_predicted_tickers_list,all_models,all_feature_importance,model,X_train,X_test = run_model_for_execution_date(execution_date,all_results,all_predicted_tickers_list,all_models,all_feature_importance,params)
# Out:
# 2005-06-30T00:00:00.000000000
# 2006-06-30T00:00:00.000000000
# 2007-06-30T00:00:00.000000000
# 2008-06-30T00:00:00.000000000
# 2009-06-30T00:00:00.000000000
# 2010-06-30T00:00:00.000000000
# 2011-06-30T00:00:00.000000000
# 2012-06-30T00:00:00.000000000
# 2013-06-30T00:00:00.000000000
# 2014-06-30T00:00:00.000000000
# 2015-06-30T00:00:00.000000000
# 2016-06-30T00:00:00.000000000
# 2017-06-30T00:00:00.000000000
# 2018-06-30T00:00:00.000000000
# 2019-06-30T00:00:00.000000000
# 2020-06-30T00:00:00.000000000

# %%
all_feature_importance = all_feature_importance.sort_values(['execution_date', 'importance'], ascending=False)

# %%
all_feature_importance_mean = all_feature_importance.groupby('feature')['importance'].mean().reset_index()
all_feature_importance_mean = all_feature_importance_mean.sort_values('importance', ascending=False)
all_feature_importance_mean_importants = all_feature_importance_mean.head(10)

# %%
ggplot(all_feature_importance_mean_importants) + geom_col(aes(x='feature', y='importance')) + coord_flip()
# Out:
# <Figure Size: (640 x 480)>

# %%
all_feature_importance['rank'] = all_feature_importance.groupby('execution_date').cumcount()
all_feature_importance_year = all_feature_importance[all_feature_importance['rank'] < 2]

# %%
ggplot(all_feature_importance_year, aes(x='execution_date', y='importance', fill='feature')) + geom_col()
# Out:
# <Figure Size: (640 x 480)>

# %%
ticker.sort_values('prob',ascending=False)
# Out:
#       Ticker       date  AssetTurnover  CashFlowFromFinancialActivities  \
# 33971   JW.B 2009-01-31         0.1744                        -142.5670
# 34411   DJCO 2009-03-31         0.1733                          -0.0400
# 36131    JNJ 2009-03-31         0.1745                         132.0000
# 35901    ROL 2009-03-31         0.4286                         -14.3090
# 35957   INFY 2009-03-31         0.2566                           4.0000
# ...      ...        ...            ...                              ...
# 34760   ARNA 2009-03-31         0.0136                          15.0640
# 33961   OPTT 2009-01-31         0.0105                           0.0000
# 35952   VBFC 2009-03-31         0.0074                           7.3343
# 35096   USEG 2009-03-31         0.0116                         -18.6960
# 35083   CYCC 2009-03-31         0.0091                          -0.3070
#
#        CashFlowFromInvestingActivities  CashFlowFromOperatingActivities  \
# 33971                         -51.4260                         242.6630
# 34411                          -2.3840                           2.6450
# 36131                       -1076.0000                        2827.0000
# 35901                          -4.9220                          20.6360
# 35957                         -18.0000                         315.0000
# ...                                ...                              ...
# 34760                          26.7550                         -51.6720
# 33961                           0.5807                          -3.2604
# 35952                          -4.2309                          -4.9078
# 35096                          14.4730                          -1.2260
# 35083                           1.4940                          -4.7930
#
#        CashOnHand  ChangeInAccountsPayable  ChangeInAccountsReceivable  \
# 33971     72.4100                   0.0000                      0.0000
# 34411     35.2250                  -0.1100                      1.0990
# 36131  13933.0000                      NaN                    -64.0000
# 35901     14.9570                      NaN                     -0.2520
# 35957   2167.0000                   2.0000                    -22.0000
# ...           ...                      ...                         ...
# 34760     70.2570                      NaN                     -0.0400
# 33961     53.3744                  -0.6582                      0.8220
# 35952     24.7965                  -0.0892                     -4.9725
# 35096     45.7860                      NaN                         NaN
# 35083     20.4420                      NaN                         NaN
#
#        ChangeInAssetsLiabilities  ChangeInInventories  \
# 33971                   147.9520                0.000
# 34411                    -0.0210                0.025
# 36131                  -172.0000             -336.000
# 35901                     0.1380               -0.699
# 35957                   -17.0000                0.000
# ...                          ...                  ...
# 34760                     0.7030                  NaN
# 33961                     0.0614                0.000
# 35952                    -1.1659                  NaN
# 35096                    -0.9940                  NaN
# 35083                     0.3030                  NaN
#
#        CommonStockDividendsPaid  CommonStockNet  ComprehensiveIncome  \
# 33971                    -7.592         83.1910            -318.7180
# 34411                     0.000          0.0150               5.7200
# 36131                 -1273.000       3120.0000           -5169.0000
# 35901                    -7.026         99.8820             -35.0760
# 35957                     0.000         64.0000                  NaN
# ...                         ...             ...                  ...
# 34760                       NaN          0.0080              -1.9380
# 33961                     0.000          0.0102              -0.7038
# 35952                       NaN         16.9224              -0.1027
# 35096                       NaN          0.2140               0.2950
# 35083                       NaN          0.0200               0.0710
#
#        CostOfGoodsSold  CurrentRatio  DaysSalesInReceivables  \
# 33971         123.2550        0.7681                 52.5510
# 34411           0.4320        2.8752                 74.9503
# 36131        4251.0000        1.6337                 58.8839
# 35901         125.3710        0.4446                 22.4607
# 35957         650.0000        5.8101                 70.0089
# ...                ...           ...                     ...
# 34760           1.3540        1.9064                 60.7788
# 33961           0.6386       14.0916                111.9559
# 35952           4.4468           NaN                     NaN
# 35096           1.7670       24.7745                450.7031
# 35083           0.1160        2.7408                     NaN
#
#        DebtIssuanceRetirementNet_minus_Total  DebtEquityRatio        EBIT  \
# 33971                              -120.1520           2.0880    226.6071
# 34411                                 0.0000              NaN     11.7280
# 36131                              2212.0000           0.3214  17572.0000
# 35901                                 2.8690           0.2738    117.7270
# 35957                                 0.0000              NaN   1374.0000
# ...                                      ...              ...         ...
# 34760                                14.7980           1.3226   -228.9220
# 33961                                 0.0000           0.0011    -20.6875
# 35952                                -8.8728           1.0626         NaN
# 35096                               -17.6880           0.0092    -10.2620
# 35083                                    NaN              NaN    -37.7710
#
#        EBITMargin      EBITDA  EBITDAMargin  FinancialActivities_minus_Other  \
# 33971     16.9028    343.8831           NaN                           0.1510
# 34411     26.6059     12.7380           NaN                           0.0000
# 36131     31.7716  20414.0000           NaN                              NaN
# 35901     10.7766    153.9680           NaN                              NaN
# 35957     29.4380   1539.0000           NaN                           0.0000
# ...           ...         ...           ...                              ...
# 34760  -1863.2050   -214.3190           NaN                              NaN
# 33961   -402.4108    -20.4070           NaN                           0.0000
# 35952         NaN         NaN           NaN                          16.2071
# 35096   -243.3949     -7.9190           NaN                              NaN
# 35083  -2287.2810    -29.0410           NaN                              NaN
#
#        GoodwillAndIntangibleAssets  GrossMargin  GrossProfit  \
# 33971                    1425.2530      67.0778     251.1280
# 34411                          NaN      95.5242       9.2200
# 36131                   28923.0000      71.7090   10775.0000
# 35901                     337.7750      48.4011     117.6010
# 35957                     142.0000      42.0161     471.0000
# ...                            ...          ...          ...
# 34760                      14.8850      49.0594       1.3040
# 33961                       0.8612      33.8112       0.3262
# 35952                       7.4221          NaN       5.3631
# 35096                          NaN     -25.4972      -0.3590
# 35083                          NaN      49.1228       0.1120
#
#        IncomeAfterTaxes  IncomeFromContinuousOperations  \
# 33971           33.4310                         33.4310
# 34411            1.6950                          1.6950
# 36131         3507.0000                       3507.0000
# 35901           15.8080                         15.8080
# 35957          321.0000                        321.0000
# ...                 ...                             ...
# 34760          -50.6140                        -50.6140
# 33961           -3.5977                         -3.5977
# 35952           -0.0751                         -0.0751
# 35096           -2.3470                         -2.3470
# 35083           -5.0630                         -5.0630
#
#        IncomeFromDiscontinuedOperations  IncomeTaxes  Inventory  \
# 33971                               NaN      10.5270    108.295
# 34411                               NaN       1.0600      0.025
# 36131                               NaN    1136.0000   5359.000
# 35901                               NaN       9.9530     11.555
# 35957                               NaN      60.0000        NaN
# ...                                 ...          ...        ...
# 34760                               NaN          NaN        NaN
# 33961                               NaN          NaN        NaN
# 35952                               NaN      -0.0387        NaN
# 35096                               NaN      -1.1120        NaN
# 35083                               NaN      -0.3580      0.460
#
#        InventoryTurnoverRatio  InvestingActivities_minus_Other  LongTermDebt  \
# 33971                  1.1381                         -37.7440      826.1250
# 34411                 17.2800                           0.0000           NaN
# 36131                  0.7932                         -66.0000     8052.0000
# 35901                 10.8499                              NaN        0.1200
# 35957                     NaN                          -3.0000           NaN
# ...                       ...                              ...           ...
# 34760                     NaN                           0.0830       85.4310
# 33961                     NaN                           0.0000        0.0954
# 35952                     NaN                          -2.3631       48.8541
# 35096                     NaN                           6.2980        0.8000
# 35083                  0.2522                              NaN           NaN
#
#        Long_minus_TermInvestments  Long_minus_termDebtCapital  \
# 33971                         NaN                      0.6602
# 34411                         NaN                         NaN
# 36131                     17.0000                      0.1553
# 35901                         NaN                      0.0005
# 35957                         NaN                         NaN
# ...                           ...                         ...
# 34760                         NaN                      0.5679
# 33961                     32.2053                      0.0011
# 35952                     25.8067                      0.3416
# 35096                      3.3640                      0.0073
# 35083                         NaN                         NaN
#
#        NetAcquisitionsDivestitures  NetCashFlow  NetChangeInIntangibleAssets  \
# 33971                       -1.361    -148.4100                       0.0000
# 34411                        0.000       1.5540                       0.0000
# 36131                    -1291.000    2050.0000                          NaN
# 35901                       -1.463     -56.4080                          NaN
# 35957                        0.000     109.0000                       0.0000
# ...                            ...          ...                          ...
# 34760                          NaN    -238.9230                          NaN
# 33961                        0.000     -97.8297                      -0.0938
# 35952                          NaN      14.6610                          NaN
# 35096                          NaN     -45.8220                          NaN
# 35083                          NaN      -9.9820                          NaN
#
#        NetChangeInInvestments_minus_Total  \
# 33971                              0.0000
# 34411                             -2.3530
# 36131                            710.0000
# 35901                                 NaN
# 35957                             46.0000
# ...                                   ...
# 34760                             28.9410
# 33961                              0.8125
# 35952                             -1.7567
# 35096                              9.4750
# 35083                              1.4830
#
#        NetChangeInLong_minus_TermInvestments  \
# 33971                                  0.000
# 34411                                 13.148
# 36131                                710.000
# 35901                                    NaN
# 35957                                  3.000
# ...                                      ...
# 34760                                    NaN
# 33961                                  0.000
# 35952                                    NaN
# 35096                                    NaN
# 35083                                    NaN
#
#        NetChangeInPropertyPlantAndEquipment  \
# 33971                              -12.3210
# 34411                               -0.0310
# 36131                             -429.0000
# 35901                               -3.4590
# 35957                              -61.0000
# ...                                     ...
# 34760                               -2.2690
# 33961                               -0.1380
# 35952                               -0.1111
# 35096                               -1.3000
# 35083                                0.0110
#
#        NetChangeInShort_minus_termInvestments  \
# 33971                                  0.0000
# 34411                                -15.5010
# 36131                                     NaN
# 35901                                     NaN
# 35957                                 43.0000
# ...                                       ...
# 34760                                 28.9410
# 33961                                  0.8125
# 35952                                 -1.7567
# 35096                                  9.4750
# 35083                                  1.4830
#
#        NetCommonEquityIssuedRepurchased  NetCurrentDebt  NetIncome  \
# 33971                           -14.974          -8.036    33.4310
# 34411                            -0.040           0.000     1.6950
# 36131                          -807.000        2219.000  3507.0000
# 35901                           -10.152           6.000    15.8080
# 35957                             4.000           0.000   321.0000
# ...                                 ...             ...        ...
# 34760                             0.266             NaN   -50.6140
# 33961                             0.000           0.000    -3.5977
# 35952                               NaN             NaN    -0.0751
# 35096                            -1.008             NaN    -2.3470
# 35083                               NaN             NaN    -5.3700
#
#        NetIncomeLoss  NetLong_minus_TermDebt  NetProfitMargin  \
# 33971        33.4310               -112.1160           8.9296
# 34411         1.6950                  0.0000          17.5611
# 36131      3507.0000                 -7.0000          23.3395
# 35901        15.8080                 -3.1310           6.5061
# 35957       321.0000                  0.0000          28.6352
# ...              ...                     ...              ...
# 34760       -50.6140                 14.7980       -1904.2140
# 33961        -3.5976                  0.0000        -372.8912
# 35952        -0.0751                 -8.8728          -1.7625
# 35096        -2.3470                -17.6880        -166.6903
# 35083        -5.0630                     NaN       -2355.2630
#
#        NetTotalEquityIssuedRepurchased  OperatingExpenses  OperatingIncome  \
# 33971                          -14.974           311.1020          63.2810
# 34411                           -0.040             7.0840           2.5680
# 36131                         -807.000         10383.0000        4643.0000
# 35901                          -10.152           216.7880          26.1840
# 35957                            4.000           791.0000         330.0000
# ...                                ...                ...              ...
# 34760                            0.266            52.1820         -49.5240
# 33961                            0.000             4.8473          -3.8825
# 35952                              NaN             9.9237          -0.1138
# 35096                           -1.008             4.8350          -3.4270
# 35083                              NaN             5.4430          -5.2150
#
#        OperatingMargin  OtherCurrentAssets  OtherIncome  \
# 33971          16.9028                 NaN          NaN
# 34411          26.6059                 NaN          NaN
# 36131          30.8998                 NaN          NaN
# 35901          10.7766             10.9190          NaN
# 35957          29.4380                 NaN          NaN
# ...                ...                 ...          ...
# 34760       -1863.2050                 NaN          NaN
# 33961        -402.4108              0.8267          NaN
# 35952              NaN                 NaN          NaN
# 35096        -243.3949                 NaN          NaN
# 35083       -2287.2810                 NaN          NaN
#
#        OtherLong_minus_TermAssets  OtherNon_minus_CashItems  \
# 33971                    132.3010                   32.3800
# 34411                         NaN                   -0.0870
# 36131                   2589.0000                 1371.0000
# 35901                      6.3960                    2.8050
# 35957                    106.0000                  191.0000
# ...                           ...                       ...
# 34760                      5.6480                    1.6830
# 33961                      2.5638                    0.4845
# 35952                     14.9178                    1.1368
# 35096                      0.9950                    1.0260
# 35083                      0.1960                   -0.1820
#
#        OtherNon_minus_CurrentLiabilities  OtherOperatingIncomeOrExpenses  \
# 33971                            94.4420                             NaN
# 34411                             3.6000                             NaN
# 36131                          4148.0000                          75.000
# 35901                            53.0680                             NaN
# 35957                            11.0000                             NaN
# ...                                  ...                             ...
# 34760                                NaN                             NaN
# 33961                             0.2628                             NaN
# 35952                             1.4479                             NaN
# 35096                             0.8730                          -1.063
# 35083                             1.4170                             NaN
#
#        OtherShareHoldersEquity  Pre_minus_PaidExpenses  Pre_minus_TaxIncome  \
# 33971                      NaN                  24.918              43.9580
# 34411                      NaN                   0.214               2.7550
# 36131                      NaN                3374.000            4643.0000
# 35901                      NaN                     NaN              25.7610
# 35957                   -570.0                  81.000             381.0000
# ...                        ...                     ...                  ...
# 34760                     -0.9                   3.898             -50.6140
# 33961                      NaN                     NaN              -3.5977
# 35952                      NaN                     NaN              -0.1138
# 35096                      NaN                   0.676              -3.4590
# 35083                      NaN                   2.529              -5.4210
#
#        Pre_minus_TaxProfitMargin  PropertyPlantAndEquipment  \
# 33971                    11.7415                   132.4540
# 34411                    28.5433                    10.4520
# 36131                    30.8998                 14253.0000
# 35901                    10.6025                    78.3250
# 35957                    33.9875                   920.0000
# ...                          ...                        ...
# 34760                 -1904.2140                    99.0280
# 33961                  -372.8911                     0.8627
# 35952                    -2.6706                    27.9753
# 35096                  -245.6676                    63.6490
# 35083                 -2377.6320                     1.5400
#
#        ROA_minus_ReturnOnAssets  ROE_minus_ReturnOnEquity  \
# 33971                    1.5576                    7.8609
# 34411                    3.0430                    4.5847
# 36131                    4.0732                    8.0085
# 35901                    2.7884                    6.9274
# 35957                    7.3472                    8.4831
# ...                         ...                       ...
# 34760                  -25.8881                  -77.8773
# 33961                   -3.9150                   -4.1360
# 35952                   -0.0130                   -0.1634
# 35096                   -1.9314                   -2.1497
# 35083                  -20.1176                  -33.3114
#
#        ROI_minus_ReturnOnInvestment  Receivables  ReceiveableTurnover  \
# 33971                        2.6715     218.6020               1.7126
# 34411                        4.5847       8.0380               1.2008
# 36131                        6.7647    9831.0000               1.5284
# 35901                        6.9238      60.6370               4.0070
# 35957                        8.4831     872.0000               1.2856
# ...                             ...          ...                  ...
# 34760                      -33.6478       1.7950               1.4808
# 33961                       -4.1315       1.2002               0.8039
# 35952                       -0.1076          NaN                  NaN
# 35096                       -2.1341       7.0510               0.1997
# 35083                      -33.3070          NaN                  NaN
#
#        ResearchAndDevelopmentExpenses  RetainedEarningsAccumulatedDeficit  \
# 33971                             NaN                            875.5730
# 34411                             NaN                             30.2910
# 36131                       7383.0000                          65398.0000
# 35901                             NaN                            145.2820
# 35957                             NaN                           3618.0000
# ...                               ...                                 ...
# 34760                        199.6260                           -761.9970
# 33961                          8.4992                            -66.5342
# 35952                             NaN                              3.3787
# 35096                             NaN                             15.3160
# 35083                         16.0800                           -207.7780
#
#        ReturnOnTangibleEquity     Revenue  SGAExpenses  ShareHolderEquity  \
# 33971                 -3.3432   1640.4221     179.4120           425.2800
# 34411                  4.5847     41.1440       6.4870            36.9710
# 36131                 23.5876  62579.0000    4608.0000         43791.0000
# 35901                -14.4260   1053.4580      81.9880           228.1950
# 35957                  8.8138   4663.0000     141.0000          3784.0000
# ...                       ...         ...          ...                ...
# 34760               -101.0118      9.8580       7.6420            64.9920
# 33961                 -4.1773      4.5267       2.1223            86.9843
# 35952                 -0.1949     35.5496       5.4769            45.9760
# 35096                 -2.1497      3.4810       2.0050           109.1780
# 35083                -33.3070      0.9280       2.2300            15.2010
#
#        Stock_minus_BasedCompensation  TotalAssets  \
# 33971                        -1.2580    2146.3290
# 34411                         0.0000      55.7010
# 36131                       159.0000   86100.0000
# 35901                         1.4500     566.9160
# 35957                         0.0000    4369.0000
# ...                              ...          ...
# 34760                         2.0210     195.5110
# 33961                         0.3154      91.8943
# 35952                         0.0455     579.6425
# 35096                         0.3870     121.5210
# 35083                        -0.1800      25.1670
#
#        TotalChangeInAssetsLiabilities  \
# 33971                        147.9520
# 34411                          0.8840
# 36131                      -2727.0000
# 35901                         -7.4130
# 35957                        -48.0000
# ...                               ...
# 34760                         -6.2090
# 33961                         -0.2228
# 35952                         -6.2275
# 35096                         -0.9940
# 35083                          0.2250
#
#        TotalCommonAndPreferredStockDividendsPaid  TotalCurrentAssets  \
# 33971                                     -7.592            424.2250
# 34411                                      0.000             43.5020
# 36131                                  -1273.000          34839.0000
# 35901                                     -7.026            117.9600
# 35957                                      0.000           3120.0000
# ...                                          ...                 ...
# 34760                                        NaN             75.9500
# 33961                                      0.000             55.4013
# 35952                                        NaN            503.5207
# 35096                                        NaN             53.5130
# 35083                                     -0.307             23.4310
#
#        TotalCurrentLiabilities  \
# 33971                 552.3350
# 34411                  15.1300
# 36131               21325.0000
# 35901                 265.3010
# 35957                 537.0000
# ...                        ...
# 34760                  39.8400
# 33961                   3.9315
# 35952                 483.3645
# 35096                   2.1600
# 35083                   8.5490
#
#        TotalDepreciationAndAmortization_minus_CashFlow  TotalLiabilities  \
# 33971                                          28.9000         1721.0490
# 34411                                           0.1530           18.7300
# 36131                                         676.0000        42309.0000
# 35901                                           9.4290          338.7210
# 35957                                          45.0000          585.0000
# ...                                                ...               ...
# 34760                                           3.4680          130.5190
# 33961                                           0.0756            4.9100
# 35952                                           0.3177          533.6665
# 35096                                           1.0890           12.3430
# 35083                                           0.2270            9.9660
#
#        TotalLiabilitiesAndShareHoldersEquity  TotalLongTermLiabilities  \
# 33971                              2146.3290                 1168.7140
# 34411                                55.7010                    3.6000
# 36131                             86100.0000                20984.0000
# 35901                               566.9160                   73.4200
# 35957                              4369.0000                   48.0000
# ...                                      ...                       ...
# 34760                               195.5110                   90.6790
# 33961                                91.8943                    0.9784
# 35952                               579.6425                   50.3020
# 35096                               121.5210                   10.1830
# 35083                                25.1670                    1.4170
#
#        TotalLong_minus_TermAssets  TotalNon_minus_CashItems  \
# 33971                   1722.1040                   61.2800
# 34411                     12.1990                    0.0660
# 36131                  51261.0000                 2047.0000
# 35901                    448.9560                   12.2340
# 35957                   1249.0000                  236.0000
# ...                           ...                       ...
# 34760                    119.5610                    5.1510
# 33961                     36.4930                    0.5601
# 35952                     76.1218                    1.4545
# 35096                     68.0080                    2.1150
# 35083                      1.7360                    0.0450
#
#        TotalNon_minus_OperatingIncomeExpense execution_date      close_0  \
# 33971                               -19.3230     2009-06-30    33.750000
# 34411                                 0.1870     2009-06-30    48.450000
# 36131                                    NaN     2009-06-30    56.800000
# 35901                                -0.4230     2009-06-30     3.419259
# 35957                                51.0000     2009-06-30     4.597500
# ...                                      ...            ...          ...
# 34760                                -1.0900     2009-06-30    49.900000
# 33961                                 0.2848     2009-06-30  1168.000000
# 35952                                    NaN     2009-06-30    75.200000
# 35096                                -0.0320     2009-06-30   120.000000
# 35083                                -0.2060     2009-06-30  1900.080000
#
#        close_sp500_0  stock_change_365  stock_change_div_365  \
# 33971      919.32394          0.143704              0.156148
# 34411      919.32394          0.407224              0.407224
# 36131      919.32394          0.039789              0.075176
# 35901      919.32394          0.195263              0.213749
# 35957      919.32394          0.628874              0.642501
# ...              ...               ...                   ...
# 34760      919.32394         -0.384770             -0.384770
# 33961      919.32394         -0.113014             -0.113014
# 35952      919.32394         -0.382979             -0.382979
# 35096      919.32394          1.375000              1.375000
# 35083      919.32394          0.520778              0.520778
#
#        sp500_change_365  stock_change_730  stock_change_div_730  \
# 33971          0.121161          0.568296              0.605630
# 34411          0.121161          0.486068              0.486068
# 36131          0.121161          0.171127              0.245070
# 35901          0.121161          0.766031              0.807048
# 35957          0.121161          0.773518              0.805351
# ...                 ...               ...                   ...
# 34760          0.121161         -0.727455             -0.727455
# 33961          0.121161         -0.388699             -0.388699
# 35952          0.121161         -0.510638             -0.510638
# 35096          0.121161          1.135000              1.135000
# 35083          0.121161          0.202476              0.202476
#
#        sp500_change_730  stock_change__minus_120  stock_change_div__minus_120  \
# 33971          0.436533                -0.124444                    -0.132444
# 34411          0.436533                -0.256966                    -0.256966
# 36131          0.436533                -0.156338                    -0.164965
# 35901          0.436533                -0.103986                    -0.108030
# 35957          0.436533                -0.380642                    -0.387643
# ...                 ...                      ...                          ...
# 34760          0.436533                -0.198397                    -0.198397
# 33961          0.436533                -0.215753                    -0.215753
# 35952          0.436533                -0.106383                    -0.106383
# 35096          0.436533                -0.225000                    -0.225000
# 35083          0.436533                -0.761185                    -0.761185
#
#        sp500_change__minus_120  stock_change__minus_365  \
# 33971                 -0.23768                 0.341333
# 34411                 -0.23768                -0.153767
# 36131                 -0.23768                 0.132746
# 35901                 -0.23768                -0.143847
# 35957                 -0.23768                 0.181620
# ...                        ...                      ...
# 34760                 -0.23768                 0.040080
# 33961                 -0.23768                 0.551370
# 35952                 -0.23768                 1.021277
# 35096                 -0.23768                 0.540000
# 35083                 -0.23768                 0.688771
#
#        stock_change_div__minus_365  sp500_change__minus_365  \
# 33971                     0.321778                 0.392329
# 34411                    -0.153767                 0.392329
# 36131                     0.099824                 0.392329
# 35901                    -0.159157                 0.392329
# 35957                     0.169538                 0.392329
# ...                            ...                      ...
# 34760                     0.040080                 0.392329
# 33961                     0.551370                 0.392329
# 35952                     1.021277                 0.392329
# 35096                     0.540000                 0.392329
# 35083                     0.688771                 0.392329
#
#        stock_change__minus_730  stock_change_div__minus_730  \
# 33971                 0.425185                     0.392593
# 34411                -0.162229                    -0.162229
# 36131                 0.088908                     0.025968
# 35901                -0.108800                    -0.137108
# 35957                 0.386623                     0.366238
# ...                        ...                          ...
# 34760                 1.164329                     1.164329
# 33961                 1.638699                     1.638699
# 35952                 2.706809                     2.706809
# 35096                 1.830000                     1.830000
# 35083                 4.702918                     4.702918
#
#        sp500_change__minus_730   std_730  std__minus_120  std__minus_365  \
# 33971                  0.65277  0.013289             NaN             NaN
# 34411                  0.65277  0.024679             NaN             NaN
# 36131                  0.65277  0.008118        0.012729        0.019999
# 35901                  0.65277  0.014990        0.024845        0.038394
# 35957                  0.65277  0.017445        0.030904        0.042436
# ...                        ...       ...             ...             ...
# 34760                  0.65277  0.056186        0.072653        0.062879
# 33961                  0.65277  0.039574        0.048663        0.057028
# 35952                  0.65277  0.058539        0.044873        0.066392
# 35096                  0.65277  0.044884        0.034302        0.037943
# 35083                  0.65277  0.063069        0.091881        0.097338
#
#        std__minus_730     Market_cap  n_finan_prev_year  Enterprisevalue  \
# 33971             NaN    1989.697500                4.0      3638.336500
# 34411             NaN      68.266050                4.0        51.771050
# 36131        0.015238  158460.640000                4.0    186836.640000
# 35901        0.031840    1739.101251                4.0      2062.865251
# 35957        0.035524   20987.757608                4.0     19405.757608
# ...               ...            ...                ...              ...
# 34760        0.050138     370.203110                4.0       430.465110
# 33961        0.050830      59.684800                4.0        11.220400
# 35952        0.050490      19.882880                4.0       528.752880
# 35096        0.033204      43.320000                4.0         9.877000
# 35083        0.071865      23.180976                4.0        12.704976
#
#        EBITDAEV    EBITEV  RevenueEV  CashOnHandEV       PFCF         PE  \
# 33971  0.094517  0.062283   0.450871      0.019902   9.868710  15.134529
# 34411  0.246045  0.226536   0.794730      0.680400   8.613333   9.141509
# 36131  0.109261  0.094050   0.334940      0.074573  13.023043  12.428884
# 35901  0.074638  0.057070   0.510677      0.007251  21.751013  24.921715
# 35957  0.079306  0.070804   0.240290      0.111668  18.673842  16.343761
# ...         ...       ...        ...           ...        ...        ...
# 34760 -0.497878 -0.531802   0.022901      0.163212  -1.652187  -1.574132
# 33961 -1.818741 -1.843740   0.403435      4.756907  -3.236139  -2.979592
# 35952       NaN       NaN   0.067233      0.046896  -2.279776  47.000000
# 35096 -0.801762 -1.038979   0.352435      4.635618  -2.054538 -20.004001
# 35083 -2.285797 -2.972930   0.073042      1.608976  -0.924740  -0.568285
#
#              PB      RDEV  WorkingCapital        ROC  DividendYieldLastYear  \
# 33971  4.621388       NaN       -128.1100  52.165539              -0.019556
# 34411  1.908066       NaN         28.3720   0.302081               0.000000
# 36131  3.578561  0.039516      13514.0000   0.632838              -0.032923
# 35901  7.576466       NaN       -147.3410        NaN              -0.015309
# 35957  5.568003       NaN       2583.0000   0.392235              -0.012083
# ...         ...       ...             ...        ...                    ...
# 34760  6.144639  0.463745         36.1100  -1.693987               0.000000
# 33961  0.685484  0.757477         51.4698  -0.395309               0.000000
# 35952  0.432524       NaN         20.1562        NaN               0.000000
# 35096  0.392575       NaN         51.3530  -0.089233               0.000000
# 35083  1.520125  1.265646         14.8820  -2.300024               0.000000
#
#        EPS_minus_EarningsPerShare_change_1_years  \
# 33971                                  -0.004464
# 34411                                   0.066398
# 36131                                   0.139651
# 35901                                   0.068536
# 35957                                   0.103137
# ...                                          ...
# 34760                                  -0.252964
# 33961                                  -0.248408
# 35952                                  -0.642857
# 35096                                  -1.039370
# 35083                                  -0.592000
#
#        EPS_minus_EarningsPerShare_change_2_years  \
# 33971                                   0.296512
# 34411                                   2.173653
# 36131                                   0.301994
# 35901                                   0.189939
# 35957                                   0.499467
# ...                                          ...
# 34760                                  -0.495283
# 33961                                  -0.373832
# 35952                                  -0.830508
# 35096                                  -3.500021
# 35083                                  -2.431033
#
#        FreeCashFlowPerShare_change_1_years  \
# 33971                            -0.215529
# 34411                             0.520270
# 36131                             0.077419
# 35901                             0.100070
# 35957                             0.433062
# ...                                    ...
# 34760                            -0.142844
# 33961                            -0.747890
# 35952                             0.548495
# 35096                             0.278385
# 35083                             0.129575
#
#        FreeCashFlowPerShare_change_2_years  \
# 33971                             0.009863
# 34411                             1.539847
# 36131                             0.013171
# 35901                             0.476056
# 35957                             1.120586
# ...                                    ...
# 34760                            -0.474201
# 33961                            -0.040981
# 35952                            -0.252290
# 35096                            -1.159937
# 35083                             0.208339
#
#        OperatingCashFlowPerShare_change_1_years  \
# 33971                                 -0.140183
# 34411                                  0.452747
# 36131                                  0.037446
# 35901                                  0.116279
# 35957                                  0.219329
# ...                                         ...
# 34760                                 -0.319060
# 33961                                 -0.701843
# 35952                                 -0.215586
# 35096                                  0.739637
# 35083                                  0.074214
#
#        OperatingCashFlowPerShare_change_2_years  EBITDA_change_1_years  \
# 33971                                  0.101472               0.060219
# 34411                                  1.185964               0.077300
# 36131                                  0.040518               0.136004
# 35901                                  0.303621               0.176028
# 35957                                  0.624277               0.176606
# ...                                         ...                    ...
# 34760                                 -0.578478              -0.271621
# 33961                                 -0.002574              -0.217936
# 35952                                 -2.236993                    NaN
# 35096                                  0.255597               0.443191
# 35083                                  0.187202               0.193888
#
#        EBITDA_change_2_years  EBIT_change_1_years  EBIT_change_2_years  \
# 33971               0.484000             0.077983             0.504166
# 34411               1.218777             0.077347             1.452018
# 36131               0.219620             0.159945             0.215214
# 35901               0.250623             0.132982             0.221741
# 35957               0.586598             0.185505             0.612676
# ...                      ...                  ...                  ...
# 34760              -1.020695            -0.281184            -0.997278
# 33961              -1.020842            -0.216504            -0.995938
# 35952                    NaN                  NaN                  NaN
# 35096               0.430546             0.302465             0.283400
# 35083              -0.057267            -0.048263            -0.324833
#
#        Revenue_change_1_years  Revenue_change_2_years  \
# 33971                0.005567                0.476587
# 34411                0.107987                0.235036
# 36131                0.005253                0.130217
# 35901                0.165631                0.216572
# 35957                0.116619                0.509061
# ...                       ...                     ...
# 34760               -0.421139               -0.577888
# 33961               -0.033066                1.242865
# 35952                0.203443                0.526297
# 35096                1.782574                3.488138
# 35083                2.653543                2.222222
#
#        NetCashFlow_change_1_years  NetCashFlow_change_2_years  \
# 33971                   -1.780276                   -1.425555
# 34411                    8.592593                    2.656471
# 36131                   -0.617823                    1.176011
# 35901                   -4.445605                  -32.959207
# 35957                   -0.835843                   -0.787938
# ...                           ...                         ...
# 34760                   -8.924524                   -3.662451
# 33961                   -2.131509                   -4.948444
# 35952                   46.573516                    9.127798
# 35096                   -2.371744                   -6.998822
# 35083                    0.777143                   -1.193795
#
#        CurrentRatio_change_1_years  CurrentRatio_change_2_years  \
# 33971                    -0.116517                    -0.157046
# 34411                     0.479088                     1.320394
# 36131                     0.066245                     0.301960
# 35901                    -0.490663                    -0.432908
# 35957                     0.020067                    -0.016887
# ...                            ...                          ...
# 34760                    -0.786642                    -0.829098
# 33961                    -0.365872                          NaN
# 35952                          NaN                          NaN
# 35096                     2.767297                     5.325189
# 35083                    -0.435724                    -0.788437
#
#        Market_cap__minus_365  Market_cap__minus_730  diff_ch_sp500  count  \
# 33971             2683.60560            2804.518600       0.034987   2240
# 34411               59.57300              58.977270       0.286063   2240
# 36131           184417.74200          180195.366000      -0.045985   2240
# 35901             1487.94293            1564.966995       0.092588   2240
# 35957            24792.75658           28520.672180       0.521340   2240
# ...                      ...                    ...            ...    ...
# 34760              382.00995             667.466660      -0.505930   2240
# 33961               92.59320              82.004580      -0.234175   2240
# 35952               24.77600              46.906624      -0.504140   2240
# 35096               73.16232             104.458080       1.253839   2240
# 35083               39.14736             117.936000       0.399617   2240
#
#        target      prob
# 33971     1.0  0.579680
# 34411     1.0  0.565804
# 36131     0.0  0.555788
# 35901     1.0  0.548638
# 35957     1.0  0.548638
# ...       ...       ...
# 34760     0.0  0.417894
# 33961     0.0  0.414654
# 35952     0.0  0.411788
# 35096     1.0  0.407390
# 35083     1.0  0.406551
#
# [2235 rows x 147 columns]

# %%
ticker_top = all_predicted_tickers[all_predicted_tickers['execution_date']=='2009-06-30'].sort_values('prob',ascending=False)
ticker_top[['Ticker', 'prob', 'close_0']].head(10)
# Out:
#       Ticker      prob    close_0
# 33971   JW.B  0.579680  33.750000
# 34411   DJCO  0.565804  48.450000
# 36131    JNJ  0.555788  56.800000
# 35901    ROL  0.548638   3.419259
# 35957   INFY  0.548638   4.597500
# 35912   MNST  0.548638   5.143333
# 35542     EW  0.546808   5.669167
# 34005    HRL  0.546388   8.635000
# 34074    MKC  0.546388  16.265000
# 34370    CHD  0.546388  13.577500

# %%
ticker_low = all_predicted_tickers[all_predicted_tickers['execution_date']=='2009-06-30'].sort_values('prob',ascending=True)
ticker_low[['Ticker', 'prob', 'close_0']].head(10)
# Out:
#       Ticker      prob      close_0
# 35083   CYCC  0.406551  1900.080000
# 35096   USEG  0.407390   120.000000
# 35952   VBFC  0.411788    75.200000
# 33961   OPTT  0.414654  1168.000000
# 34514   RIOT  0.417894   640.800000
# 34760   ARNA  0.417894    49.900000
# 36056   SEED  0.418002    46.400000
# 34496    FBC  0.420078    68.000000
# 35648    SAL  0.421112    24.310000
# 34867    TRQ  0.423804    37.381549

# %%
import shap

def get_shap_values(execution_date,ticker=None):
    date = np.datetime64(execution_date)
    model = all_models[date]
    X_test = all_predicted_tickers[all_predicted_tickers['execution_date']==date]
    fn = model.booster_.feature_name()
    if ticker is not None:
        X_test = X_test[X_test['Ticker']==ticker]
    X_test['Ticker'] = X_test['Ticker'].astype('category')
    X_test = X_test.sort_values('Ticker')
    if ticker is not None:
        explainer = shap.Explainer(model)
        shap_values = explainer(X_test[fn])
        shap_values = shap_values[:,:,1]
    else:
        explainer = shap.Explainer(model,X_test[fn])
        shap_values = explainer(X_test[fn])
    return shap_values

# %%
sv = get_shap_values('2009-06-30T00:00:00.000000000')
shap.plots.bar(sv,max_display=8)

# %%
shap.plots.beeswarm(sv)

# %%
sv_top_ticker = get_shap_values('2009-06-30T00:00:00.000000000', 'JW.B')
shap.plots.waterfall(sv_top_ticker[0])

# %%
sv_low_ticker = get_shap_values('2009-06-30T00:00:00.000000000', 'CYCC')
shap.plots.waterfall(sv_low_ticker[0])
